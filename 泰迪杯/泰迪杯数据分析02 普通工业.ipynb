# %%
import numpy as np
import pandas as pd
from pandas import  DataFrame

import seaborn as sns 
import matplotlib.pyplot as plt 
from colorama import Fore

from sklearn.metrics import mean_absolute_error, mean_squared_error
import math

import warnings # Supress warnings 
warnings.filterwarnings('ignore')
plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号
np.random.seed(7)

df = pd.read_csv(r"./泰迪杯数据01_普通工业.csv")
df
# Out:
#      行业类型         日期1  有功功率最大值（kw）  有功功率最小值（kw）  最高温度  最低温度  白天风力风向  夜晚风力风向  \
# 0    普通工业  2019-01-01    6179.9364    4093.0467    12     7       1       1
# 1    普通工业  2019-01-02   10711.9704    3971.5308    11     6       1       1
# 2    普通工业  2019-01-03   10079.0262    4033.8369    15     9       1       1
# 3    普通工业  2019-01-04    9713.3055    4145.8497    17    12       1       1
# 4    普通工业  2019-01-05    6958.3842    3965.1792    17    12       1       1
# ..    ...         ...          ...          ...   ...   ...     ...     ...
# 973  普通工业  2021-08-27   10332.7482    2867.6274    35    26       1       1
# 974  普通工业  2021-08-28    6337.3656    3288.4884    33    26       1       1
# 975  普通工业  2021-08-29    6509.8032    3192.6312    32    25       1       1
# 976  普通工业  2021-08-30   10606.9374    3287.0472    34    26       1       1
# 977  普通工业  2021-08-31   10329.5676    3732.4056    32    26       1       1
#
#      天气1  天气2
# 0    5.0  5.0
# 1    8.0  8.0
# 2    3.0  8.0
# 3    5.0  8.0
# 4    5.0  8.0
# ..   ...  ...
# 973  7.0  7.0
# 974  7.0  3.0
# 975  7.0  7.0
# 976  6.0  6.0
# 977  7.0  6.0
#
# [978 rows x 10 columns]

# %%
df.columns
df  = df.rename(columns={'日期1':'date'}) #将日期1改为date

# %%
from datetime import datetime, date 

df['date'] = pd.to_datetime(df['date'])
df.head().style.set_properties(subset=['date'], **{'background-color': 'dodgerblue'}) #将date变为蓝色
# Out:
# <style type="text/css">
# #T_759f8_row0_col1, #T_759f8_row1_col1, #T_759f8_row2_col1, #T_759f8_row3_col1, #T_759f8_row4_col1 {
#   background-color: dodgerblue;
# }
# </style>
# <table id="T_759f8_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >行业类型</th>
#       <th class="col_heading level0 col1" >date</th>
#       <th class="col_heading level0 col2" >有功功率最大值（kw）</th>
#       <th class="col_heading level0 col3" >有功功率最小值（kw）</th>
#       <th class="col_heading level0 col4" >最高温度</th>
#       <th class="col_heading level0 col5" >最低温度</th>
#       <th class="col_heading level0 col6" >白天风力风向</th>
#       <th class="col_heading level0 col7" >夜晚风力风向</th>
#       <th class="col_heading level0 col8" >天气1</th>
#       <th class="col_heading level0 col9" >天气2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_759f8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_759f8_row0_col0" class="data row0 col0" >普通工业</td>
#       <td id="T_759f8_row0_col1" class="data row0 col1" >2019-01-01 00:00:00</td>
#       <td id="T_759f8_row0_col2" class="data row0 col2" >6179.936400</td>
#       <td id="T_759f8_row0_col3" class="data row0 col3" >4093.046700</td>
#       <td id="T_759f8_row0_col4" class="data row0 col4" >12</td>
#       <td id="T_759f8_row0_col5" class="data row0 col5" >7</td>
#       <td id="T_759f8_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_759f8_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_759f8_row0_col8" class="data row0 col8" >5.000000</td>
#       <td id="T_759f8_row0_col9" class="data row0 col9" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_759f8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_759f8_row1_col0" class="data row1 col0" >普通工业</td>
#       <td id="T_759f8_row1_col1" class="data row1 col1" >2019-01-02 00:00:00</td>
#       <td id="T_759f8_row1_col2" class="data row1 col2" >10711.970400</td>
#       <td id="T_759f8_row1_col3" class="data row1 col3" >3971.530800</td>
#       <td id="T_759f8_row1_col4" class="data row1 col4" >11</td>
#       <td id="T_759f8_row1_col5" class="data row1 col5" >6</td>
#       <td id="T_759f8_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_759f8_row1_col7" class="data row1 col7" >1</td>
#       <td id="T_759f8_row1_col8" class="data row1 col8" >8.000000</td>
#       <td id="T_759f8_row1_col9" class="data row1 col9" >8.000000</td>
#     </tr>
#     <tr>
#       <th id="T_759f8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_759f8_row2_col0" class="data row2 col0" >普通工业</td>
#       <td id="T_759f8_row2_col1" class="data row2 col1" >2019-01-03 00:00:00</td>
#       <td id="T_759f8_row2_col2" class="data row2 col2" >10079.026200</td>
#       <td id="T_759f8_row2_col3" class="data row2 col3" >4033.836900</td>
#       <td id="T_759f8_row2_col4" class="data row2 col4" >15</td>
#       <td id="T_759f8_row2_col5" class="data row2 col5" >9</td>
#       <td id="T_759f8_row2_col6" class="data row2 col6" >1</td>
#       <td id="T_759f8_row2_col7" class="data row2 col7" >1</td>
#       <td id="T_759f8_row2_col8" class="data row2 col8" >3.000000</td>
#       <td id="T_759f8_row2_col9" class="data row2 col9" >8.000000</td>
#     </tr>
#     <tr>
#       <th id="T_759f8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_759f8_row3_col0" class="data row3 col0" >普通工业</td>
#       <td id="T_759f8_row3_col1" class="data row3 col1" >2019-01-04 00:00:00</td>
#       <td id="T_759f8_row3_col2" class="data row3 col2" >9713.305500</td>
#       <td id="T_759f8_row3_col3" class="data row3 col3" >4145.849700</td>
#       <td id="T_759f8_row3_col4" class="data row3 col4" >17</td>
#       <td id="T_759f8_row3_col5" class="data row3 col5" >12</td>
#       <td id="T_759f8_row3_col6" class="data row3 col6" >1</td>
#       <td id="T_759f8_row3_col7" class="data row3 col7" >1</td>
#       <td id="T_759f8_row3_col8" class="data row3 col8" >5.000000</td>
#       <td id="T_759f8_row3_col9" class="data row3 col9" >8.000000</td>
#     </tr>
#     <tr>
#       <th id="T_759f8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_759f8_row4_col0" class="data row4 col0" >普通工业</td>
#       <td id="T_759f8_row4_col1" class="data row4 col1" >2019-01-05 00:00:00</td>
#       <td id="T_759f8_row4_col2" class="data row4 col2" >6958.384200</td>
#       <td id="T_759f8_row4_col3" class="data row4 col3" >3965.179200</td>
#       <td id="T_759f8_row4_col4" class="data row4 col4" >17</td>
#       <td id="T_759f8_row4_col5" class="data row4 col5" >12</td>
#       <td id="T_759f8_row4_col6" class="data row4 col6" >1</td>
#       <td id="T_759f8_row4_col7" class="data row4 col7" >1</td>
#       <td id="T_759f8_row4_col8" class="data row4 col8" >5.000000</td>
#       <td id="T_759f8_row4_col9" class="data row4 col9" >8.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.isna().sum()
# Out:
# 行业类型            0
# date            0
# 有功功率最大值（kw）     0
# 有功功率最小值（kw）     0
# 最高温度            0
# 最低温度            0
# 白天风力风向          0
# 夜晚风力风向          0
# 天气1            10
# 天气2             3
# dtype: int64

# %%
df = df.fillna(method='ffill',axis=0)

# %%
df.drop('date', axis=1).columns
# Out:
# Index(['行业类型', '有功功率最大值（kw）', '有功功率最小值（kw）', '最高温度', '最低温度', '白天风力风向',
#        '夜晚风力风向', '天气1', '天气2'],
#       dtype='object')

# %%
# To compelte the data, as naive method, we will use ffill
f, ax = plt.subplots(nrows=9, ncols=1, figsize=(15, 25))

for i, column in enumerate(df.drop('date', axis=1).columns):  #enumerate将组成一个遍历序列
    sns.lineplot(x=df['date'], y=df[column].fillna(method='ffill'), ax=ax[i], color='dodgerblue')  #lineplot方法画图
    ax[i].set_title('Feature: {}'.format(column), fontsize=14) #显示标题
    ax[i].set_ylabel(ylabel=column, fontsize=14) #显示y轴变量

#     ax[i].set_xlim([date(2019, 1, 1), date(2021, 8, 31)]) #设置x轴的范围

# %%
#补缺失值
df['有功功率最大值（kw）'] = df['有功功率最大值（kw）'].interpolate()
df['有功功率最小值（kw）'] = df['有功功率最小值（kw）'].interpolate()
df.index = df['date']

# %% [markdown]
# ## 4 数据平滑与采样

# %%
# 行重复删除
df[df.index.duplicated()]
df = df[~df.index.duplicated()]

# %%
fig, ax = plt.subplots(nrows=3,ncols=1, sharex=True, figsize=(16,12))

sns.lineplot(x=df['date'],y=df['有功功率最大值（kw）'],ax=ax[0])
ax[0].set_title('有功功率最大值（kw） Volume')
ax[0].set_ylabel(ylabel='总有功率',fontsize=14)

ts = df['有功功率最大值（kw）'].resample('W',closed='left').mean()
sns.lineplot(x=df['date'],y=ts,ax=ax[1])
ax[1].set_title('Weekly 有功功率最大值（kw） Volume')
ax[1].set_ylabel(ylabel='有功功率最大值（kw）',fontsize=14)

ts = df['有功功率最大值（kw）'].resample('M',closed='left').mean()
sns.lineplot(x=df['date'],y=ts,ax=ax[2])
ax[2].set_title('Monthly 有功功率最大值（kw） Volume')
ax[2].set_ylabel(ylabel='有功功率最大值（kw）',fontsize=14)


for i in range(3):
#     ax[i].set_xlim([date(2019,1,1),date(2021,8,31)])
    plt.show()

# %%
fig, ax = plt.subplots(nrows=3,ncols=1, sharex=True, figsize=(16,12))

sns.lineplot(x=df['date'],y=df['有功功率最小值（kw）'],ax=ax[0])
ax[0].set_title('有功功率最小值（kw） Volume')
ax[0].set_ylabel(ylabel='总有功率',fontsize=14)

ts = df['有功功率最小值（kw）'].resample('W',closed='left').mean()
sns.lineplot(x=df['date'],y=ts,ax=ax[1])
ax[1].set_title('Weekly 有功功率最小值（kw） Volume')
ax[1].set_ylabel(ylabel='有功功率最小值（kw）',fontsize=14)

ts = df['有功功率最小值（kw）'].resample('M',closed='left').mean()
sns.lineplot(x=df['date'],y=ts,ax=ax[2])
ax[2].set_title('Monthly 有功功率最小值（kw） Volume')
ax[2].set_ylabel(ylabel='有功功率最小值（kw）',fontsize=14)


for i in range(3):
#     ax[i].set_xlim([date(2019,1,1),date(2021,8,31)])
    plt.show()

# %% [markdown]
# ## 5 平稳性检验

# %%
rolling_window = 52
f, ax = plt.subplots(nrows=1, ncols=1, figsize=(15, 8))

ts = df['有功功率最大值（kw）'].resample('W',closed='left').mean()
ts1 = df['有功功率最大值（kw）'].resample('W',closed='left').std()
sns.lineplot(x=df['date'],y=df['有功功率最大值（kw）'],ax=ax)
sns.lineplot(x=df['date'],y=ts,ax=ax,label='mean')
sns.lineplot(x=df['date'],y=ts1,ax=ax,label='std')
ax.set_ylabel(ylabel='有功功率最大值（kw） Volume', fontsize=14)
# ax.set_xlim([date(2019, 1, 1), date(2021, 8, 31)])
plt.tight_layout()
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller

result = adfuller(df['有功功率最大值（kw）'].values)
result
#p值小于0.05，第一个值比第五个值小，趋势平稳
# Out:
# (-2.2249825919373047,
#  0.19730347062339626,
#  21,
#  951,
#  {'1%': -3.4372448882473177,
#   '5%': -2.86458394997689,
#   '10%': -2.5683907715382888},
#  16202.941713321768)

# %%
# Thanks to https://www.kaggle.com/iamleonie for this function!
f, ax = plt.subplots(nrows=1, ncols=1, figsize=(12, 6))

def visualize_adfuller_results(series, title, ax):
    sns.lineplot(x=df['date'],y=series,ax=ax)
    ax.set_title(result)
    ax.set_ylabel(title)
#     ax.set_xlim([date(2019, 1, 1), date(2021, 8, 31)])

visualize_adfuller_results(df['有功功率最大值（kw）'].values, '有功功率最大值（kw）',ax=ax)
# visualize_adfuller_results(df['temperature'].values, 'Temperature', ax[1, 0])
# visualize_adfuller_results(df['river_hydrometry'].values, 'River_Hydrometry', ax[0, 1])
# visualize_adfuller_results(df['drainage_volume'].values, 'Drainage_Volume', ax[1, 1])
# visualize_adfuller_results(df['depth_to_groundwater'].values, 'Depth_to_Groundwater', ax[2, 0])

# f.delaxes(ax[2, 1])
plt.tight_layout()
plt.show()

# %%
rolling_window = 52
f, ax = plt.subplots(nrows=1, ncols=1, figsize=(15, 8))

ts = df['有功功率最小值（kw）'].resample('W',closed='left').mean()
ts1 = df['有功功率最小值（kw）'].resample('W',closed='left').std()
sns.lineplot(x=df['date'],y=df['有功功率最小值（kw）'],ax=ax)
sns.lineplot(x=df['date'],y=ts,ax=ax,label='mean')
sns.lineplot(x=df['date'],y=ts1,ax=ax,label='std')
ax.set_ylabel(ylabel='有功功率最小值（kw） Volume', fontsize=14)
# ax.set_xlim([date(2019, 1, 1), date(2021, 8, 31)])
plt.tight_layout()
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller

result = adfuller(df['有功功率最小值（kw）'].values)
result
#p值小于0.05，第一个值比第五个值小，趋势平稳
# Out:
# (-2.944116848064617,
#  0.040453089176061045,
#  13,
#  959,
#  {'1%': -3.43718721587049,
#   '5%': -2.8645585177815187,
#   '10%': -2.568377225331392},
#  15214.79023240403)

# %%
# Thanks to https://www.kaggle.com/iamleonie for this function!
f, ax = plt.subplots(nrows=1, ncols=1, figsize=(12, 6))

def visualize_adfuller_results(series, title, ax):
    sns.lineplot(x=df['date'],y=series,ax=ax)
    ax.set_title(result)
    ax.set_ylabel(title)
    ax.set_xlim([date(2019, 1, 1), date(2021, 8, 31)])

visualize_adfuller_results(df['有功功率最小值（kw）'].values, '有功功率最小值（kw）',ax=ax)
# visualize_adfuller_results(df['temperature'].values, 'Temperature', ax[1, 0])
# visualize_adfuller_results(df['river_hydrometry'].values, 'River_Hydrometry', ax[0, 1])
# visualize_adfuller_results(df['drainage_volume'].values, 'Drainage_Volume', ax[1, 1])
# visualize_adfuller_results(df['depth_to_groundwater'].values, 'Depth_to_Groundwater', ax[2, 0])

# f.delaxes(ax[2, 1])
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 异常值处理

# %%
from scipy.stats import kstest
#正态检测
u = df['有功功率最大值（kw）'].mean()
# 计算标准差
std = df['有功功率最大值（kw）'].std()
# 计算P值
res=kstest(df['有功功率最大值（kw）'].astype(float),  'norm', (u, std))[1]
print(res)
# 判断p值是否服从正态分布，p<=0.05 则服从正态分布，否则不服从。
if res<=0.05:
    print('该列数据服从正态分布------------')
    print('均值为：%.3f，标准差为：%.3f' % (u, std))
    print('------------------------------')
else:
    print("错误")

#KS检验3σ异常点检测
sum =[]
# 计算均值
u = df['有功功率最大值（kw）'].mean()
# 计算标准差
std = df['有功功率最大值（kw）'].std()
# 定义3σ法则识别异常值
# 识别异常值
error = df['有功功率最大值（kw）'][np.abs(df['有功功率最大值（kw）'] - u) > 3 * std]
df.loc[error.index,'总有功功率（kw）'] = np.nan
# 剔除异常值，保留正常的数据
data_c = df['有功功率最大值（kw）'][np.abs(df['有功功率最大值（kw）'] - u) <= 3 * std]
# 输出异常数据
sum.append(error)
# print(error)
# Out:
# 3.1146618804218976e-05
# 该列数据服从正态分布------------
# 均值为：7946.061，标准差为：3187.489
# ------------------------------

# %%
df = df.fillna(method='ffill',axis=0)  #异常处理

f, ax = plt.subplots(nrows=1, ncols=1, figsize=(15, 6))
visualize_adfuller_results(df['有功功率最大值（kw）'],'df' , ax=ax)

# %%
from scipy.stats import kstest
#正态检测
u = df['有功功率最小值（kw）'].mean()
# 计算标准差
std = df['有功功率最小值（kw）'].std()
# 计算P值
res=kstest(df['有功功率最小值（kw）'].astype(float),  'norm', (u, std))[1]
print(res)
# 判断p值是否服从正态分布，p<=0.05 则服从正态分布，否则不服从。
if res<=0.05:
    print('该列数据服从正态分布------------')
    print('均值为：%.3f，标准差为：%.3f' % (u, std))
    print('------------------------------')
else:
    print("错误")

#KS检验3σ异常点检测
sum =[]
# 计算均值
u = df['有功功率最小值（kw）'].mean()
# 计算标准差
std = df['有功功率最小值（kw）'].std()
# 定义3σ法则识别异常值
# 识别异常值
error = df['有功功率最小值（kw）'][np.abs(df['有功功率最小值（kw）'] - u) > 3 * std]
df.loc[error.index,'总有功功率（kw）'] = np.nan
# 剔除异常值，保留正常的数据
data_c = df['有功功率最小值（kw）'][np.abs(df['有功功率最小值（kw）'] - u) <= 3 * std]
# 输出异常数据
sum.append(error)
# print(error)
# Out:
# 0.003339892758321763
# 该列数据服从正态分布------------
# 均值为：3355.642，标准差为：1241.922
# ------------------------------

# %%
df = df.fillna(method='ffill',axis=0)  #异常处理

f, ax = plt.subplots(nrows=1, ncols=1, figsize=(15, 6))
visualize_adfuller_results(df['有功功率最小值（kw）'],'df' , ax=ax)

# %%
df['有功功率最大值（kw）'] = df['有功功率最大值（kw）'].astype(float)
df['有功功率最小值（kw）'] = df['有功功率最小值（kw）'].astype(float)
df['最高温度'] = df['最高温度'].astype(float)
df['最低温度'] = df['最低温度'].astype(float)
df['白天风力风向'] = df['白天风力风向'].astype(float)
df['夜晚风力风向'] = df['夜晚风力风向'].astype(float)
df['天气1'] = df['天气1'].astype(float)
df['天气2'] = df['天气2'].astype(float)

# %%
f, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 8))

shifted_cols = df.columns[1:9]
corrmat = df[shifted_cols].corr()  #输出函数的相关性

sns.heatmap(corrmat, annot=True, vmin=-1, vmax=1, cmap='coolwarm_r')  #画出相关性的热力图
ax.set_title('Correlation Matrix of Lagged Features', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix of Lagged Features')

# %% [markdown]
# ## LSTM普通工业最大功率三十天预测

# %%
test_size = 91  #预测测试值范围
train_size =  610 #预测训练值范围
df = df.fillna(0)
univariate_df = df[['date', '有功功率最大值（kw）']][:701].copy()
univariate_df.columns = ['ds', 'y']


# LSTM对输入数据的大小敏感，需要对输入数据做标准化处理
# 使用MinMaxScaler将数据映射到0-1区间
from sklearn.preprocessing import MinMaxScaler
data = univariate_df.filter(['y'])
dataset = data.values
scaler = MinMaxScaler(feature_range=(-1, 0))
scaled_data = scaler.fit_transform(dataset)

scaled_data[-10:]
# Out:
# array([[-0.72513957],
#        [-0.6342015 ],
#        [-0.6434512 ],
#        [-0.63236134],
#        [-0.62170482],
#        [-0.65572141],
#        [-0.7679642 ],
#        [-0.80021266],
#        [-0.65941424],
#        [-0.65588686]])

# %%
def check(du):
    #正态检测
    u = du.mean()
    # 计算标准差
    std = du.std()
    # 计算P值
    res=kstest(du.astype(float),  'norm', (u, std))[1]
    print(res)
    # 判断p值是否服从正态分布，p<=0.05 则服从正态分布，否则不服从。
    if res<=0.05:
        print('该列数据服从正态分布------------')
        print('均值为：%.3f，标准差为：%.3f' % (u, std))
        print('------------------------------')
    else:
        print("错误")

def sta(sta_du):
    stas = []
    u = sta_du.mean()
    std = sta_du.std()
    for i in sta_du:
        stas.append((i-u)/(std*std))
    return stas

# %%
du_day_max = df['最高温度'][:701]
du_day_min = df['最低温度'][:701]

#温度标准化
from scipy.stats import kstest
check(du_day_max)
check(du_day_min)
du_day_max = sta(du_day_max)
du_day_min = sta(du_day_min)
# Out:
# 3.300002051892593e-06
# 该列数据服从正态分布------------
# 均值为：27.877，标准差为：6.021
# ------------------------------
# 7.194159637281362e-13
# 该列数据服从正态分布------------
# 均值为：20.709，标准差为：5.725
# ------------------------------

# %%
f, ax = plt.subplots(nrows=1, ncols=1, figsize=(20, 6))
sns.distplot(du_day_min, ax=ax,color='green',label='du_day_max') #直方图和核密度图的结合，查看单个连续型变量的分布
sns.distplot(du_day_max, ax=ax, color='orange',label='du_day_min') #直方图和核密度图的结合，查看单个连续型变量的分布
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
du_day_max = list(map(list, zip(du_day_max)))
du_day_min = list(map(list, zip(du_day_min)))

# %%
look_back = 7 # 96
# 将数据分为训练集、测试集
train, test = scaled_data[:train_size-look_back,:], scaled_data[train_size-look_back:,:]

# 生成t-x数据
def create_dataset(dataset, look_back):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# 设置随机种子，保证复现

np.random.seed(7)


x_train, y_train = create_dataset(train, look_back)
x_test, y_test = create_dataset(test, look_back)

#添加特征列
x_train = np.append(x_train,du_day_max[0:train_size-look_back*2],axis=1)
x_train = np.append(x_train,du_day_min[0:train_size-look_back*2],axis=1)
x_test = np.append(x_test,du_day_max[train_size:],axis=1)
x_test = np.append(x_test,du_day_min[train_size:],axis=1)


# LSTM网络的输入为【批次大小(行数)，时间步长，特征数量(列数)】
# 将数据转换为符合输入的格式
x_train = np.reshape(x_train, (x_train.shape[0], 1, x_train.shape[1]))
x_test = np.reshape(x_test, (x_test.shape[0], 1, x_test.shape[1]))

print(len(x_train), len(x_test))
# Out:
# 596 91

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM

# 创建LSTM模型，拟合数据
model = Sequential()

# 添加128个LSTM神经元的隐层网络
model.add(LSTM(128, input_shape=(x_train.shape[1], x_train.shape[2]))) #return_sequences=True
#model.add(LSTM(64, return_sequences=False))
model.add(Dense(30))
#model.add(Dense(1))

# 损失函数与adam优化器
model.compile(optimizer='adam', loss='mean_squared_error')

# 训练数据10期, batch_size:一次训练抓取的样本数量
model.fit(x_train, y_train, batch_size=16, epochs=150 )  #validation_data=(x_test, y_test)

model.summary()
# Out:
# Epoch 1/150
# 38/38 [==============================] - 1s 2ms/step - loss: 0.1645
# Epoch 2/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0195
# Epoch 3/150
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0145
# Epoch 4/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0141
# Epoch 5/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0136
# Epoch 6/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0131
# Epoch 7/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0125
# Epoch 8/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0119
# Epoch 9/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0112
# Epoch 10/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0109
# Epoch 11/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0101
# Epoch 12/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0096
# Epoch 13/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0091
# Epoch 14/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0088
# Epoch 15/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0087
# Epoch 16/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0085
# Epoch 17/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0085
# Epoch 18/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0087
# Epoch 19/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0083
# Epoch 20/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0084
# Epoch 21/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0081
# Epoch 22/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0082
# Epoch 23/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0083
# Epoch 24/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0082
# Epoch 25/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0082
# Epoch 26/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0081
# Epoch 27/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0080
# Epoch 28/150
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0081
# Epoch 29/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0080
# Epoch 30/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0081
# Epoch 31/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0082
# Epoch 32/150
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0081
# Epoch 33/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0079
# Epoch 34/150
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0080
# Epoch 35/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0079
# Epoch 36/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0080
# Epoch 37/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0079
# Epoch 38/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0080
# Epoch 39/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0078
# Epoch 40/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0082
# Epoch 41/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0079
# Epoch 42/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0081
# Epoch 43/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0080
# Epoch 44/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0080
# Epoch 45/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0079
# Epoch 46/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0079
# Epoch 47/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0082
# Epoch 48/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0078
# Epoch 49/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0079
# Epoch 50/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0078
# Epoch 51/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0078
# Epoch 52/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0079
# Epoch 53/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0078
# Epoch 54/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0078
# Epoch 55/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0078
# Epoch 56/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0079
# Epoch 57/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0078
# Epoch 58/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0078
# Epoch 59/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0077
# Epoch 60/150
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0079
# Epoch 61/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0078
# Epoch 62/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0078
# Epoch 63/150
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0077
# Epoch 64/150
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0077
# Epoch 65/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0078
# Epoch 66/150
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0077
# Epoch 67/150
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0077
# Epoch 68/150
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0077
# Epoch 69/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0077
# Epoch 70/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0077
# Epoch 71/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0078
# Epoch 72/150
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0083
# Epoch 73/150
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0078
# Epoch 74/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0078
# Epoch 75/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0079
# Epoch 76/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0076
# Epoch 77/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0076
# Epoch 78/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0076
# Epoch 79/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0076
# Epoch 80/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0076
# Epoch 81/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0078
# Epoch 82/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0077
# Epoch 83/150
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0077
# Epoch 84/150
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0076
# Epoch 85/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0077
# Epoch 86/150
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0075
# Epoch 87/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0076
# Epoch 88/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0076
# Epoch 89/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0075
# Epoch 90/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0075
# Epoch 91/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0075
# Epoch 92/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0075
# Epoch 93/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0076
# Epoch 94/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0075
# Epoch 95/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0075
# Epoch 96/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0075
# Epoch 97/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0074
# Epoch 98/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0076
# Epoch 99/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0074
# Epoch 100/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0078
# Epoch 101/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0074
# Epoch 102/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0074
# Epoch 103/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0075
# Epoch 104/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0075
# Epoch 105/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0075
# Epoch 106/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0074
# Epoch 107/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0075
# Epoch 108/150
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0073
# Epoch 109/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0074
# Epoch 110/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0072
# Epoch 111/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0073
# Epoch 112/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0073
# Epoch 113/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0072
# Epoch 114/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0072
# Epoch 115/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0072
# Epoch 116/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0073
# Epoch 117/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0074
# Epoch 118/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0073
# Epoch 119/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0071
# Epoch 120/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0072
# Epoch 121/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0071
# Epoch 122/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0072
# Epoch 123/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0072
# Epoch 124/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0074
# Epoch 125/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0071
# Epoch 126/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0071
# Epoch 127/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0071
# Epoch 128/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0071
# Epoch 129/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0072
# Epoch 130/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0072
# Epoch 131/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0070
# Epoch 132/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0070
# Epoch 133/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0070
# Epoch 134/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0070
# Epoch 135/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0071
# Epoch 136/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0070
# Epoch 137/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0071
# Epoch 138/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0070
# Epoch 139/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0069
# Epoch 140/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0071
# Epoch 141/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0069
# Epoch 142/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0071
# Epoch 143/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0071
# Epoch 144/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0069
# Epoch 145/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0071
# Epoch 146/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0071
# Epoch 147/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0070
# Epoch 148/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0070
# Epoch 149/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0070
# Epoch 150/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0069
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 128)               70656
# _________________________________________________________________
# dense (Dense)                (None, 30)                3870
# =================================================================
# Total params: 74,526
# Trainable params: 74,526
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 预测
#train_predict = model.predict(x_train)
test_predict = model.predict(x_test) # 3个月的数据

# 前面把数据缩放到0-1范围。
# 现在跟实际值做比较，将预测值反标准化，从0-1范围转换为原数据范围
#train_predict = scaler.inverse_transform(train_predict)
#y_train = scaler.inverse_transform([y_train])

test_predict = scaler.inverse_transform(test_predict)
y_test = scaler.inverse_transform([y_test])

# 评估RMSE误差
score_rmse = np.sqrt(mean_squared_error(y_test[0], test_predict[:,1]))
score_mae = mean_absolute_error(y_test[0], test_predict[:,1])
print(Fore.GREEN + 'RMSE: {}'.format(score_rmse))
from sklearn.metrics import r2_score
print('R2-score:',r2_score(y_test[0], test_predict[:,1]))
# Out:
# RMSE: 1390.498463210002
# R2-score: 0.7313182995266856

# %%
# 准备画图 - 训练数据
x_train_ticks = univariate_df.head(train_size)['ds']
y_train = univariate_df.head(train_size)['y']
x_test_ticks = univariate_df.tail(test_predict[:,0].size)['ds']

# 准备画图 - 测试数据
f, ax = plt.subplots(1)
f.set_figheight(6)
f.set_figwidth(15)

sns.lineplot(x=x_train_ticks[-30:], y=y_train[-30:], ax=ax, label='Train Set') #navajowhite
sns.lineplot(x=x_test_ticks, y=test_predict[:,0], ax=ax, color='green', label='Prediction') #navajowhite
sns.lineplot(x=x_test_ticks, y=y_test[0], ax=ax, color='orange', label='Ground truth') #navajowhite

ax.set_title(f'Prediction \n MAE: {score_mae:.2f}, RMSE: {score_rmse:.2f}', fontsize=14)
ax.set_xlabel(xlabel='Date', fontsize=14)
ax.set_ylabel(ylabel='有功功率最大值', fontsize=14)
plt.show()

# %%
day_max=test_predict[:,0]
day_index = pd.date_range(start='2020-09-01',end='2020-11-30',freq='D')
day_index = pd.DataFrame(day_index,columns=['date_day'])

day_max = pd.DataFrame(day_max,columns=['min'])
day_max = pd.concat((day_max,day_index),axis=1)
day_max.index = day_max['date_day']

# %%
for i in range(test_predict['sum'].count()):
    if (test_predict.iloc[i,0] == test_predict['sum'].max()):
        print("\n最大值为：",test_predict.iloc[i,0])
        print("最大日期为：",test_predict.iloc[i,1])
    if (test_predict.iloc[i,0] == test_predict['sum'].min()):
        print("\n最小值为：",test_predict.iloc[i,0])
        print("最小日期为：",test_predict.iloc[i,1])
print(f'\nPrediction \n MAE: {score_mae:.2f}, RMSE: {score_rmse:.2f}')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [36], in <cell line: 1>()
# ----> 1 for i in range(test_predict['sum'].count()):
#       2     if (test_predict.iloc[i,0] == test_predict['sum'].max()):
#       3         print("\n最大值为：",test_predict.iloc[i,0])
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %% [markdown]
# ## LSTM普通工业最小功率三十天预测

# %%
test_size = 91  #预测测试值范围
train_size = 610  #预测训练值范围
df = df.fillna(0)
univariate_df = df[['date', '有功功率最小值（kw）']][:701].copy()
univariate_df.columns = ['ds', 'y']



# LSTM对输入数据的大小敏感，需要对输入数据做标准化处理
# 使用MinMaxScaler将数据映射到0-1区间
from sklearn.preprocessing import MinMaxScaler
data = univariate_df.filter(['y'])
dataset = data.values
scaler = MinMaxScaler(feature_range=(-1, 0))
scaled_data = scaler.fit_transform(dataset)

scaled_data[-10:]
# Out:
# array([[-0.61471855],
#        [-0.63180902],
#        [-0.64533342],
#        [-0.63160757],
#        [-0.62416708],
#        [-0.64883274],
#        [-0.65988222],
#        [-0.69285246],
#        [-0.67343509],
#        [-0.66509999]])

# %%
def check(du):
    #正态检测
    u = du.mean()
    # 计算标准差
    std = du.std()
    # 计算P值
    res=kstest(du.astype(float),  'norm', (u, std))[1]
    print(res)
    # 判断p值是否服从正态分布，p<=0.05 则服从正态分布，否则不服从。
    if res<=0.05:
        print('该列数据服从正态分布------------')
        print('均值为：%.3f，标准差为：%.3f' % (u, std))
        print('------------------------------')
    else:
        print("错误")

def sta(sta_du):
    stas = []
    u = sta_du.mean()
    std = sta_du.std()
    for i in sta_du:
        stas.append((i-u)/(std*std))
    return stas

# %%
du_day_max = df['最高温度'][:701]
du_day_min = df['最低温度'][:701]

#温度标准化
from scipy.stats import kstest
check(du_day_max)
check(du_day_min)
du_day_max = sta(du_day_max)
du_day_min = sta(du_day_min)
# Out:
# 3.300002051892593e-06
# 该列数据服从正态分布------------
# 均值为：27.877，标准差为：6.021
# ------------------------------
# 7.194159637281362e-13
# 该列数据服从正态分布------------
# 均值为：20.709，标准差为：5.725
# ------------------------------

# %%
f, ax = plt.subplots(nrows=1, ncols=1, figsize=(20, 6))
sns.distplot(du_day_min, ax=ax,color='green',label='du_day_max') #直方图和核密度图的结合，查看单个连续型变量的分布
sns.distplot(du_day_max, ax=ax, color='orange',label='du_day_min') #直方图和核密度图的结合，查看单个连续型变量的分布
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
du_day_max = list(map(list, zip(du_day_max)))
du_day_min = list(map(list, zip(du_day_min)))

# %%
look_back = 7 # 96
# 将数据分为训练集、测试集
train, test = scaled_data[:train_size-look_back,:], scaled_data[train_size-look_back:,:]

# 生成t-x数据
def create_dataset(dataset, look_back):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# 设置随机种子，保证复现

np.random.seed(7)


x_train, y_train = create_dataset(train, look_back)
x_test, y_test = create_dataset(test, look_back)

#添加特征列
x_train = np.append(x_train,du_day_max[0:train_size-look_back*2],axis=1)
x_train = np.append(x_train,du_day_min[0:train_size-look_back*2],axis=1)
x_test = np.append(x_test,du_day_max[train_size:],axis=1)
x_test = np.append(x_test,du_day_min[train_size:],axis=1)


# LSTM网络的输入为【批次大小(行数)，时间步长，特征数量(列数)】
# 将数据转换为符合输入的格式
x_train = np.reshape(x_train, (x_train.shape[0], 1, x_train.shape[1]))
x_test = np.reshape(x_test, (x_test.shape[0], 1, x_test.shape[1]))

print(len(x_train), len(x_test))
# Out:
# 596 91

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM

# 创建LSTM模型，拟合数据
model = Sequential()

# 添加128个LSTM神经元的隐层网络
model.add(LSTM(128, input_shape=(x_train.shape[1], x_train.shape[2]))) #return_sequences=True
#model.add(LSTM(64, return_sequences=False))
model.add(Dense(30))
#model.add(Dense(1))

# 损失函数与adam优化器
model.compile(optimizer='adam', loss='mean_squared_error')

# 训练数据10期, batch_size:一次训练抓取的样本数量
model.fit(x_train, y_train, batch_size=16, epochs=150 )  #validation_data=(x_test, y_test)

model.summary()
# Out:
# Epoch 1/150
# 38/38 [==============================] - 1s 2ms/step - loss: 0.1306
# Epoch 2/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0201
# Epoch 3/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0173
# Epoch 4/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0169
# Epoch 5/150
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0167
# Epoch 6/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0163
# Epoch 7/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0162
# Epoch 8/150
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0156
# Epoch 9/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0155
# Epoch 10/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0151
# Epoch 11/150
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0148
# Epoch 12/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0146
# Epoch 13/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0145
# Epoch 14/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0145
# Epoch 15/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0143
# Epoch 16/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0142
# Epoch 17/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0139
# Epoch 18/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0140
# Epoch 19/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0139
# Epoch 20/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0137
# Epoch 21/150
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0138
# Epoch 22/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0136
# Epoch 23/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0137
# Epoch 24/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0136
# Epoch 25/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0137
# Epoch 26/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0139
# Epoch 27/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0138
# Epoch 28/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0136
# Epoch 29/150
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0135
# Epoch 30/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0135
# Epoch 31/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0136
# Epoch 32/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0135
# Epoch 33/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0135
# Epoch 34/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0135
# Epoch 35/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0136
# Epoch 36/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0137
# Epoch 37/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0136
# Epoch 38/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0135
# Epoch 39/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0135
# Epoch 40/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0134
# Epoch 41/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0134
# Epoch 42/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0137
# Epoch 43/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0134
# Epoch 44/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0135
# Epoch 45/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0133
# Epoch 46/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0135
# Epoch 47/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0135
# Epoch 48/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0135
# Epoch 49/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0145
# Epoch 50/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0133
# Epoch 51/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0140
# Epoch 52/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0134
# Epoch 53/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0136
# Epoch 54/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0135
# Epoch 55/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0133
# Epoch 56/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0133
# Epoch 57/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0136
# Epoch 58/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0133
# Epoch 59/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0134
# Epoch 60/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0133
# Epoch 61/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0133
# Epoch 62/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0134
# Epoch 63/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0134
# Epoch 64/150
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0135
# Epoch 65/150
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0131
# Epoch 66/150
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0134
# Epoch 67/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0131
# Epoch 68/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0135
# Epoch 69/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0133
# Epoch 70/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0131
# Epoch 71/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0132
# Epoch 72/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0134
# Epoch 73/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0139
# Epoch 74/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0133
# Epoch 75/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0132
# Epoch 76/150
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0130
# Epoch 77/150
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0136
# Epoch 78/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0132
# Epoch 79/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0131
# Epoch 80/150
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0133
# Epoch 81/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0133
# Epoch 82/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0130
# Epoch 83/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0131
# Epoch 84/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0132
# Epoch 85/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0131
# Epoch 86/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0132
# Epoch 87/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0131
# Epoch 88/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0129
# Epoch 89/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0130
# Epoch 90/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0129
# Epoch 91/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0128
# Epoch 92/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0129
# Epoch 93/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0129
# Epoch 94/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0128
# Epoch 95/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0128
# Epoch 96/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0130
# Epoch 97/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0128
# Epoch 98/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0130
# Epoch 99/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0129
# Epoch 100/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0128
# Epoch 101/150
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0128
# Epoch 102/150
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0126
# Epoch 103/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0129
# Epoch 104/150
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0130
# Epoch 105/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0128
# Epoch 106/150
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0129
# Epoch 107/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0127
# Epoch 108/150
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0127
# Epoch 109/150
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0129
# Epoch 110/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0132
# Epoch 111/150
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0127
# Epoch 112/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0127
# Epoch 113/150
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0128
# Epoch 114/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0125
# Epoch 115/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0126
# Epoch 116/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0127
# Epoch 117/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0125
# Epoch 118/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0124
# Epoch 119/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0126
# Epoch 120/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0126
# Epoch 121/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0126
# Epoch 122/150
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0126
# Epoch 123/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0126
# Epoch 124/150
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0127
# Epoch 125/150
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0125
# Epoch 126/150
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0126
# Epoch 127/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0124
# Epoch 128/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0124
# Epoch 129/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0125
# Epoch 130/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0129
# Epoch 131/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0125
# Epoch 132/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0125
# Epoch 133/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0124
# Epoch 134/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0124
# Epoch 135/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0124
# Epoch 136/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0125
# Epoch 137/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0125
# Epoch 138/150
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0124
# Epoch 139/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0123
# Epoch 140/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0123
# Epoch 141/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0123
# Epoch 142/150
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0122
# Epoch 143/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0123
# Epoch 144/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0124
# Epoch 145/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0124
# Epoch 146/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0122
# Epoch 147/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0123
# Epoch 148/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0123
# Epoch 149/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0124
# Epoch 150/150
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0123
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 128)               70656
# _________________________________________________________________
# dense_1 (Dense)              (None, 30)                3870
# =================================================================
# Total params: 74,526
# Trainable params: 74,526
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 预测
#train_predict = model.predict(x_train)
test_predict = model.predict(x_test) # 3个月的数据

# 前面把数据缩放到0-1范围。
# 现在跟实际值做比较，将预测值反标准化，从0-1范围转换为原数据范围
#train_predict = scaler.inverse_transform(train_predict)
#y_train = scaler.inverse_transform([y_train])

test_predict = scaler.inverse_transform(test_predict)
y_test = scaler.inverse_transform([y_test])

# 评估RMSE误差
score_rmse = np.sqrt(mean_squared_error(y_test[0], test_predict[:,1]))
score_mae = mean_absolute_error(y_test[0], test_predict[:,1])
print(Fore.GREEN + 'RMSE: {}'.format(score_rmse))
from sklearn.metrics import r2_score
print('R2-score:',r2_score(y_test[0], test_predict[:,1]))
# Out:
# RMSE: 666.1576648184499
# R2-score: 0.41887777239288715

# %%
# 准备画图 - 训练数据
x_train_ticks = univariate_df.head(train_size)['ds']
y_train = univariate_df.head(train_size)['y']
x_test_ticks = univariate_df.tail(test_predict[:,0].size)['ds']

# 准备画图 - 测试数据
f, ax = plt.subplots(1)
f.set_figheight(6)
f.set_figwidth(15)

sns.lineplot(x=x_train_ticks[-30:], y=y_train[-30:], ax=ax, label='Train Set') #navajowhite
sns.lineplot(x=x_test_ticks, y=test_predict[:,0], ax=ax, color='green', label='Prediction') #navajowhite
sns.lineplot(x=x_test_ticks, y=y_test[0], ax=ax, color='orange', label='Ground truth') #navajowhite

ax.set_title(f'Prediction \n MAE: {score_mae:.2f}, RMSE: {score_rmse:.2f}', fontsize=14)
ax.set_xlabel(xlabel='Date', fontsize=14)
ax.set_ylabel(ylabel='有功功率最大值', fontsize=14)
plt.show()

# %%
day_min = test_predict[:,0]
day_index = pd.date_range(start='2021-09-01',end='2021-11-30',freq='D')
day_index = pd.DataFrame(day_index,columns=['date_day'])

day_min = pd.DataFrame(day_min,columns=['max'])
day_min = pd.concat((day_min,day_index),axis=1)
day_min.index = day_min['date_day']

# %%
day_max.to_csv("数据预测普通工业30天max.csv",index=False,encoding='utf_8_sig')
day_min.to_csv("数据预测普通工业30天min.csv",index=False,encoding='utf_8_sig')

# %%
for i in range(test_predict['sum'].count()):
    if (test_predict.iloc[i,0] == test_predict['sum'].max()):
        print("\n最大值为：",test_predict.iloc[i,0])
        print("最大日期为：",test_predict.iloc[i,1])
    if (test_predict.iloc[i,0] == test_predict['sum'].min()):
        print("\n最小值为：",test_predict.iloc[i,0])
        print("最小日期为：",test_predict.iloc[i,1])
print(f'\nPrediction \n MAE: {score_mae:.2f}, RMSE: {score_rmse:.2f}')
# Out:
# 最大值为： 4150.972
# 最大日期为： 2021-07-07 00:00:00
#
# 最小值为： 1561.4087
# 最小日期为： 2021-08-10 00:00:00
#
# Prediction
#  MAE: 438.72, RMSE: 607.79
