# %%
import numpy as np
import pandas as pd
from pandas import  DataFrame

import seaborn as sns 
import matplotlib.pyplot as plt 
from colorama import Fore

from sklearn.metrics import mean_absolute_error, mean_squared_error
import math

import warnings # Supress warnings 
warnings.filterwarnings('ignore')
plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号
np.random.seed(7)

df = pd.read_csv(r"./泰迪杯数据01_非普工业.csv")
df
# Out:
#      行业类型         日期1  有功功率最大值（kw）  有功功率最小值（kw）  最高温度  最低温度  白天风力风向  夜晚风力风向  \
# 0    非普工业  2019-10-10    2621.3316     892.5384    32    25       1       1
# 1    非普工业  2019-10-11    2669.0172     978.3816    33    25       1       1
# 2    非普工业  2019-10-12    2632.9704    1020.0588    33    24       1       1
# 3    非普工业  2019-10-13    1810.2156     965.6964    31    23       1       1
# 4    非普工业  2019-10-14    2522.4576     943.8792    29    23       1       1
# ..    ...         ...          ...          ...   ...   ...     ...     ...
# 691  非普工业  2021-08-27    3207.7014    1416.9294    35    26       1       1
# 692  非普工业  2021-08-28    2418.1716    1291.5816    33    26       1       1
# 693  非普工业  2021-08-29    2486.0946    1420.2804    32    25       1       1
# 694  非普工业  2021-08-30    3316.1904    1434.9684    34    26       1       1
# 695  非普工业  2021-08-31    3223.6920    1401.9822    32    26       1       1
#
#      天气1  天气2
# 0    3.0  3.0
# 1    0.0  0.0
# 2    3.0  7.0
# 3    7.0  7.0
# 4    3.0  3.0
# ..   ...  ...
# 691  7.0  7.0
# 692  7.0  3.0
# 693  7.0  7.0
# 694  6.0  6.0
# 695  7.0  6.0
#
# [696 rows x 10 columns]

# %%
df.columns
df  = df.rename(columns={'日期1':'date'}) #将日期1改为date

# %%
from datetime import datetime, date 

df['date'] = pd.to_datetime(df['date'])
df.head().style.set_properties(subset=['date'], **{'background-color': 'dodgerblue'}) #将date变为蓝色
# Out:
# <style type="text/css">
# #T_0cf5a_row0_col1, #T_0cf5a_row1_col1, #T_0cf5a_row2_col1, #T_0cf5a_row3_col1, #T_0cf5a_row4_col1 {
#   background-color: dodgerblue;
# }
# </style>
# <table id="T_0cf5a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >行业类型</th>
#       <th class="col_heading level0 col1" >date</th>
#       <th class="col_heading level0 col2" >有功功率最大值（kw）</th>
#       <th class="col_heading level0 col3" >有功功率最小值（kw）</th>
#       <th class="col_heading level0 col4" >最高温度</th>
#       <th class="col_heading level0 col5" >最低温度</th>
#       <th class="col_heading level0 col6" >白天风力风向</th>
#       <th class="col_heading level0 col7" >夜晚风力风向</th>
#       <th class="col_heading level0 col8" >天气1</th>
#       <th class="col_heading level0 col9" >天气2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0cf5a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0cf5a_row0_col0" class="data row0 col0" >非普工业</td>
#       <td id="T_0cf5a_row0_col1" class="data row0 col1" >2019-10-10 00:00:00</td>
#       <td id="T_0cf5a_row0_col2" class="data row0 col2" >2621.331600</td>
#       <td id="T_0cf5a_row0_col3" class="data row0 col3" >892.538400</td>
#       <td id="T_0cf5a_row0_col4" class="data row0 col4" >32</td>
#       <td id="T_0cf5a_row0_col5" class="data row0 col5" >25</td>
#       <td id="T_0cf5a_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_0cf5a_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_0cf5a_row0_col8" class="data row0 col8" >3.000000</td>
#       <td id="T_0cf5a_row0_col9" class="data row0 col9" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0cf5a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0cf5a_row1_col0" class="data row1 col0" >非普工业</td>
#       <td id="T_0cf5a_row1_col1" class="data row1 col1" >2019-10-11 00:00:00</td>
#       <td id="T_0cf5a_row1_col2" class="data row1 col2" >2669.017200</td>
#       <td id="T_0cf5a_row1_col3" class="data row1 col3" >978.381600</td>
#       <td id="T_0cf5a_row1_col4" class="data row1 col4" >33</td>
#       <td id="T_0cf5a_row1_col5" class="data row1 col5" >25</td>
#       <td id="T_0cf5a_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_0cf5a_row1_col7" class="data row1 col7" >1</td>
#       <td id="T_0cf5a_row1_col8" class="data row1 col8" >0.000000</td>
#       <td id="T_0cf5a_row1_col9" class="data row1 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0cf5a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0cf5a_row2_col0" class="data row2 col0" >非普工业</td>
#       <td id="T_0cf5a_row2_col1" class="data row2 col1" >2019-10-12 00:00:00</td>
#       <td id="T_0cf5a_row2_col2" class="data row2 col2" >2632.970400</td>
#       <td id="T_0cf5a_row2_col3" class="data row2 col3" >1020.058800</td>
#       <td id="T_0cf5a_row2_col4" class="data row2 col4" >33</td>
#       <td id="T_0cf5a_row2_col5" class="data row2 col5" >24</td>
#       <td id="T_0cf5a_row2_col6" class="data row2 col6" >1</td>
#       <td id="T_0cf5a_row2_col7" class="data row2 col7" >1</td>
#       <td id="T_0cf5a_row2_col8" class="data row2 col8" >3.000000</td>
#       <td id="T_0cf5a_row2_col9" class="data row2 col9" >7.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0cf5a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0cf5a_row3_col0" class="data row3 col0" >非普工业</td>
#       <td id="T_0cf5a_row3_col1" class="data row3 col1" >2019-10-13 00:00:00</td>
#       <td id="T_0cf5a_row3_col2" class="data row3 col2" >1810.215600</td>
#       <td id="T_0cf5a_row3_col3" class="data row3 col3" >965.696400</td>
#       <td id="T_0cf5a_row3_col4" class="data row3 col4" >31</td>
#       <td id="T_0cf5a_row3_col5" class="data row3 col5" >23</td>
#       <td id="T_0cf5a_row3_col6" class="data row3 col6" >1</td>
#       <td id="T_0cf5a_row3_col7" class="data row3 col7" >1</td>
#       <td id="T_0cf5a_row3_col8" class="data row3 col8" >7.000000</td>
#       <td id="T_0cf5a_row3_col9" class="data row3 col9" >7.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0cf5a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0cf5a_row4_col0" class="data row4 col0" >非普工业</td>
#       <td id="T_0cf5a_row4_col1" class="data row4 col1" >2019-10-14 00:00:00</td>
#       <td id="T_0cf5a_row4_col2" class="data row4 col2" >2522.457600</td>
#       <td id="T_0cf5a_row4_col3" class="data row4 col3" >943.879200</td>
#       <td id="T_0cf5a_row4_col4" class="data row4 col4" >29</td>
#       <td id="T_0cf5a_row4_col5" class="data row4 col5" >23</td>
#       <td id="T_0cf5a_row4_col6" class="data row4 col6" >1</td>
#       <td id="T_0cf5a_row4_col7" class="data row4 col7" >1</td>
#       <td id="T_0cf5a_row4_col8" class="data row4 col8" >3.000000</td>
#       <td id="T_0cf5a_row4_col9" class="data row4 col9" >3.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.isna().sum()
# Out:
# 行业类型           0
# date           0
# 有功功率最大值（kw）    0
# 有功功率最小值（kw）    0
# 最高温度           0
# 最低温度           0
# 白天风力风向         0
# 夜晚风力风向         0
# 天气1            4
# 天气2            1
# dtype: int64

# %%
df = df.fillna(method='ffill',axis=0)

# %%
df.drop('date', axis=1).columns
# Out:
# Index(['行业类型', '有功功率最大值（kw）', '有功功率最小值（kw）', '最高温度', '最低温度', '白天风力风向',
#        '夜晚风力风向', '天气1', '天气2'],
#       dtype='object')

# %%
# To compelte the data, as naive method, we will use ffill
f, ax = plt.subplots(nrows=9, ncols=1, figsize=(15, 25))

for i, column in enumerate(df.drop('date', axis=1).columns):  #enumerate将组成一个遍历序列
    sns.lineplot(x=df['date'], y=df[column].fillna(method='ffill'), ax=ax[i], color='dodgerblue')  #lineplot方法画图
    ax[i].set_title('Feature: {}'.format(column), fontsize=14) #显示标题
    ax[i].set_ylabel(ylabel=column, fontsize=14) #显示y轴变量

#     ax[i].set_xlim([date(2019, 1, 1), date(2021, 8, 31)]) #设置x轴的范围

# %%
#补缺失值
df['有功功率最大值（kw）'] = df['有功功率最大值（kw）'].interpolate()
df['有功功率最小值（kw）'] = df['有功功率最小值（kw）'].interpolate()
df.index = df['date']

# %% [markdown]
# ## 4 数据平滑与采样

# %%
# 行重复删除
df[df.index.duplicated()]
df = df[~df.index.duplicated()]

# %%
fig, ax = plt.subplots(nrows=3,ncols=1, sharex=True, figsize=(16,12))

sns.lineplot(x=df['date'],y=df['有功功率最大值（kw）'],ax=ax[0])
ax[0].set_title('有功功率最大值（kw） Volume')
ax[0].set_ylabel(ylabel='总有功率',fontsize=14)

ts = df['有功功率最大值（kw）'].resample('W',closed='left').mean()
sns.lineplot(x=df['date'],y=ts,ax=ax[1])
ax[1].set_title('Weekly 有功功率最大值（kw） Volume')
ax[1].set_ylabel(ylabel='有功功率最大值（kw）',fontsize=14)

ts = df['有功功率最大值（kw）'].resample('M',closed='left').mean()
sns.lineplot(x=df['date'],y=ts,ax=ax[2])
ax[2].set_title('Monthly 有功功率最大值（kw） Volume')
ax[2].set_ylabel(ylabel='有功功率最大值（kw）',fontsize=14)


for i in range(3):
#     ax[i].set_xlim([date(2019,1,1),date(2021,8,31)])
    plt.show()

# %%
fig, ax = plt.subplots(nrows=3,ncols=1, sharex=True, figsize=(16,12))

sns.lineplot(x=df['date'],y=df['有功功率最小值（kw）'],ax=ax[0])
ax[0].set_title('有功功率最小值（kw） Volume')
ax[0].set_ylabel(ylabel='总有功率',fontsize=14)

ts = df['有功功率最小值（kw）'].resample('W',closed='left').mean()
sns.lineplot(x=df['date'],y=ts,ax=ax[1])
ax[1].set_title('Weekly 有功功率最小值（kw） Volume')
ax[1].set_ylabel(ylabel='有功功率最小值（kw）',fontsize=14)

ts = df['有功功率最小值（kw）'].resample('M',closed='left').mean()
sns.lineplot(x=df['date'],y=ts,ax=ax[2])
ax[2].set_title('Monthly 有功功率最小值（kw） Volume')
ax[2].set_ylabel(ylabel='有功功率最小值（kw）',fontsize=14)


for i in range(3):
#     ax[i].set_xlim([date(2019,1,1),date(2021,8,31)])
    plt.show()

# %% [markdown]
# ## 5 平稳性检验

# %%
rolling_window = 52
f, ax = plt.subplots(nrows=1, ncols=1, figsize=(15, 8))

ts = df['有功功率最大值（kw）'].resample('W',closed='left').mean()
ts1 = df['有功功率最大值（kw）'].resample('W',closed='left').std()
sns.lineplot(x=df['date'],y=df['有功功率最大值（kw）'],ax=ax)
sns.lineplot(x=df['date'],y=ts,ax=ax,label='mean')
sns.lineplot(x=df['date'],y=ts1,ax=ax,label='std')
ax.set_ylabel(ylabel='有功功率最大值（kw） Volume', fontsize=14)
# ax.set_xlim([date(2019, 1, 1), date(2021, 8, 31)])
plt.tight_layout()
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller

result = adfuller(df['有功功率最大值（kw）'].values)
result
#p值小于0.05，第一个值比第五个值小，趋势平稳
# Out:
# (-1.4031320516699668,
#  0.5807736558718932,
#  20,
#  670,
#  {'1%': -3.4401478069875613,
#   '5%': -2.8658634456698464,
#   '10%': -2.5690723769213633},
#  9420.140130773745)

# %%
# Thanks to https://www.kaggle.com/iamleonie for this function!
f, ax = plt.subplots(nrows=1, ncols=1, figsize=(12, 6))

def visualize_adfuller_results(series, title, ax):
    sns.lineplot(x=df['date'],y=series,ax=ax)
    ax.set_title(result)
    ax.set_ylabel(title)
#     ax.set_xlim([date(2019, 1, 1), date(2021, 8, 31)])

visualize_adfuller_results(df['有功功率最大值（kw）'].values, '有功功率最大值（kw）',ax=ax)
# visualize_adfuller_results(df['temperature'].values, 'Temperature', ax[1, 0])
# visualize_adfuller_results(df['river_hydrometry'].values, 'River_Hydrometry', ax[0, 1])
# visualize_adfuller_results(df['drainage_volume'].values, 'Drainage_Volume', ax[1, 1])
# visualize_adfuller_results(df['depth_to_groundwater'].values, 'Depth_to_Groundwater', ax[2, 0])

# f.delaxes(ax[2, 1])
plt.tight_layout()
plt.show()

# %%
rolling_window = 52
f, ax = plt.subplots(nrows=1, ncols=1, figsize=(15, 8))

ts = df['有功功率最小值（kw）'].resample('W',closed='left').mean()
ts1 = df['有功功率最小值（kw）'].resample('W',closed='left').std()
sns.lineplot(x=df['date'],y=df['有功功率最小值（kw）'],ax=ax)
sns.lineplot(x=df['date'],y=ts,ax=ax,label='mean')
sns.lineplot(x=df['date'],y=ts1,ax=ax,label='std')
ax.set_ylabel(ylabel='有功功率最小值（kw） Volume', fontsize=14)
# ax.set_xlim([date(2019, 1, 1), date(2021, 8, 31)])
plt.tight_layout()
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller

result = adfuller(df['有功功率最小值（kw）'].values)
result
#p值小于0.05，第一个值比第五个值小，趋势平稳
# Out:
# (-1.8685596690020818,
#  0.3469930569105028,
#  13,
#  677,
#  {'1%': -3.4400461122487807,
#   '5%': -2.8658186431652357,
#   '10%': -2.5690485069240654},
#  9070.27627808639)

# %%
# Thanks to https://www.kaggle.com/iamleonie for this function!
f, ax = plt.subplots(nrows=1, ncols=1, figsize=(12, 6))

def visualize_adfuller_results(series, title, ax):
    sns.lineplot(x=df['date'],y=series,ax=ax)
    ax.set_title(result)
    ax.set_ylabel(title)
    ax.set_xlim([date(2019, 1, 1), date(2021, 8, 31)])

visualize_adfuller_results(df['有功功率最小值（kw）'].values, '有功功率最小值（kw）',ax=ax)
# visualize_adfuller_results(df['temperature'].values, 'Temperature', ax[1, 0])
# visualize_adfuller_results(df['river_hydrometry'].values, 'River_Hydrometry', ax[0, 1])
# visualize_adfuller_results(df['drainage_volume'].values, 'Drainage_Volume', ax[1, 1])
# visualize_adfuller_results(df['depth_to_groundwater'].values, 'Depth_to_Groundwater', ax[2, 0])

# f.delaxes(ax[2, 1])
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 异常值处理

# %%
from scipy.stats import kstest
#正态检测
u = df['有功功率最大值（kw）'].mean()
# 计算标准差
std = df['有功功率最大值（kw）'].std()
# 计算P值
res=kstest(df['有功功率最大值（kw）'].astype(float),  'norm', (u, std))[1]
print(res)
# 判断p值是否服从正态分布，p<=0.05 则服从正态分布，否则不服从。
if res<=0.05:
    print('该列数据服从正态分布------------')
    print('均值为：%.3f，标准差为：%.3f' % (u, std))
    print('------------------------------')
else:
    print("错误")

#KS检验3σ异常点检测
sum =[]
# 计算均值
u = df['有功功率最大值（kw）'].mean()
# 计算标准差
std = df['有功功率最大值（kw）'].std()
# 定义3σ法则识别异常值
# 识别异常值
error = df['有功功率最大值（kw）'][np.abs(df['有功功率最大值（kw）'] - u) > 3 * std]
df.loc[error.index,'总有功功率（kw）'] = np.nan
# 剔除异常值，保留正常的数据
data_c = df['有功功率最大值（kw）'][np.abs(df['有功功率最大值（kw）'] - u) <= 3 * std]
# 输出异常数据
sum.append(error)
# print(error)
# Out:
# 0.0027123658311335366
# 该列数据服从正态分布------------
# 均值为：2478.586，标准差为：868.389
# ------------------------------

# %%
df = df.fillna(method='ffill',axis=0)  #异常处理

f, ax = plt.subplots(nrows=1, ncols=1, figsize=(15, 6))
visualize_adfuller_results(df['有功功率最大值（kw）'],'df' , ax=ax)

# %%
from scipy.stats import kstest
#正态检测
u = df['有功功率最小值（kw）'].mean()
# 计算标准差
std = df['有功功率最小值（kw）'].std()
# 计算P值
res=kstest(df['有功功率最小值（kw）'].astype(float),  'norm', (u, std))[1]
print(res)
# 判断p值是否服从正态分布，p<=0.05 则服从正态分布，否则不服从。
if res<=0.05:
    print('该列数据服从正态分布------------')
    print('均值为：%.3f，标准差为：%.3f' % (u, std))
    print('------------------------------')
else:
    print("错误")

#KS检验3σ异常点检测
sum =[]
# 计算均值
u = df['有功功率最小值（kw）'].mean()
# 计算标准差
std = df['有功功率最小值（kw）'].std()
# 定义3σ法则识别异常值
# 识别异常值
error = df['有功功率最小值（kw）'][np.abs(df['有功功率最小值（kw）'] - u) > 3 * std]
df.loc[error.index,'总有功功率（kw）'] = np.nan
# 剔除异常值，保留正常的数据
data_c = df['有功功率最小值（kw）'][np.abs(df['有功功率最小值（kw）'] - u) <= 3 * std]
# 输出异常数据
sum.append(error)
# print(error)
# Out:
# 0.06281890700338932
# 错误

# %%
df = df.fillna(method='ffill',axis=0)  #异常处理

f, ax = plt.subplots(nrows=1, ncols=1, figsize=(15, 6))
visualize_adfuller_results(df['有功功率最小值（kw）'],'df' , ax=ax)

# %%
df['有功功率最大值（kw）'] = df['有功功率最大值（kw）'].astype(float)
df['有功功率最小值（kw）'] = df['有功功率最小值（kw）'].astype(float)
df['最高温度'] = df['最高温度'].astype(float)
df['最低温度'] = df['最低温度'].astype(float)
df['白天风力风向'] = df['白天风力风向'].astype(float)
df['夜晚风力风向'] = df['夜晚风力风向'].astype(float)
df['天气1'] = df['天气1'].astype(float)
df['天气2'] = df['天气2'].astype(float)

# %%
f, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 8))

shifted_cols = df.columns[1:9]
corrmat = df[shifted_cols].corr()  #输出函数的相关性

sns.heatmap(corrmat, annot=True, vmin=-1, vmax=1, cmap='coolwarm_r')  #画出相关性的热力图
ax.set_title('Correlation Matrix of Lagged Features', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix of Lagged Features')

# %% [markdown]
# ## LSTM非普工业最大功率三十天预测

# %%
test_size = 90  #预测测试值范围
train_size = len(df) - test_size  #预测训练值范围
df = df.fillna(0)
univariate_df = df[['date', '有功功率最大值（kw）']].copy()
univariate_df.columns = ['ds', 'y']


# LSTM对输入数据的大小敏感，需要对输入数据做标准化处理
# 使用MinMaxScaler将数据映射到0-1区间
from sklearn.preprocessing import MinMaxScaler
data = univariate_df.filter(['y'])
dataset = data.values
scaler = MinMaxScaler(feature_range=(-1, 0))
scaled_data = scaler.fit_transform(dataset)

scaled_data[-10:]
# Out:
# array([[-0.58905148],
#        [-0.3625439 ],
#        [-0.33875296],
#        [-0.34070491],
#        [-0.31440374],
#        [-0.36076743],
#        [-0.56403925],
#        [-0.54655184],
#        [-0.33283592],
#        [-0.3566505 ]])

# %%
def check(du):
    #正态检测
    u = du.mean()
    # 计算标准差
    std = du.std()
    # 计算P值
    res=kstest(du.astype(float),  'norm', (u, std))[1]
    print(res)
    # 判断p值是否服从正态分布，p<=0.05 则服从正态分布，否则不服从。
    if res<=0.05:
        print('该列数据服从正态分布------------')
        print('均值为：%.3f，标准差为：%.3f' % (u, std))
        print('------------------------------')
    else:
        print("错误")

def sta(sta_du):
    stas = []
    u = sta_du.mean()
    std = sta_du.std()
    for i in sta_du:
        stas.append((i-u)/(std*std))
    return stas

# %%
du_day_max = df['最高温度']
du_day_min = df['最低温度']

#温度标准化
from scipy.stats import kstest
check(du_day_max)
check(du_day_min)
du_day_max = sta(du_day_max)
du_day_min = sta(du_day_min)
# Out:
# 3.574350681268186e-05
# 该列数据服从正态分布------------
# 均值为：27.734，标准差为：6.059
# ------------------------------
# 1.8130741067440147e-12
# 该列数据服从正态分布------------
# 均值为：20.148，标准差为：6.031
# ------------------------------

# %%
f, ax = plt.subplots(nrows=1, ncols=1, figsize=(20, 6))
sns.distplot(du_day_min, ax=ax,color='green',label='du_day_max') #直方图和核密度图的结合，查看单个连续型变量的分布
sns.distplot(du_day_max, ax=ax, color='orange',label='du_day_min') #直方图和核密度图的结合，查看单个连续型变量的分布
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
du_day_max = list(map(list, zip(du_day_max)))
du_day_min = list(map(list, zip(du_day_min)))

# %%
look_back = 7 # 96
# 将数据分为训练集、测试集
train, test = scaled_data[:train_size-look_back,:], scaled_data[train_size-look_back:,:]

# 生成t-x数据
def create_dataset(dataset, look_back):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# 设置随机种子，保证复现

np.random.seed(7)


x_train, y_train = create_dataset(train, look_back)
x_test, y_test = create_dataset(test, look_back)

#添加特征列
x_train = np.append(x_train,du_day_max[0:train_size-look_back*2],axis=1)
x_train = np.append(x_train,du_day_min[0:train_size-look_back*2],axis=1)
x_test = np.append(x_test,du_day_max[train_size:],axis=1)
x_test = np.append(x_test,du_day_min[train_size:],axis=1)


# LSTM网络的输入为【批次大小(行数)，时间步长，特征数量(列数)】
# 将数据转换为符合输入的格式
x_train = np.reshape(x_train, (x_train.shape[0], 1, x_train.shape[1]))
x_test = np.reshape(x_test, (x_test.shape[0], 1, x_test.shape[1]))

print(len(x_train), len(x_test))
# Out:
# 587 90

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM

# 创建LSTM模型，拟合数据
model = Sequential()

# 添加128个LSTM神经元的隐层网络
model.add(LSTM(128, input_shape=(x_train.shape[1], x_train.shape[2]))) #return_sequences=True
#model.add(LSTM(64, return_sequences=False))
model.add(Dense(30))
#model.add(Dense(1))

# 损失函数与adam优化器
model.compile(optimizer='adam', loss='mean_squared_error')

# 训练数据10期, batch_size:一次训练抓取的样本数量
model.fit(x_train, y_train, batch_size=16, epochs=150 )  #validation_data=(x_test, y_test)

model.summary()
# Out:
# Epoch 1/150
# 37/37 [==============================] - 1s 2ms/step - loss: 0.2232
# Epoch 2/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0170
# Epoch 3/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0103
# Epoch 4/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0100
# Epoch 5/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0099
# Epoch 6/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0097
# Epoch 7/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0096
# Epoch 8/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0094
# Epoch 9/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0092
# Epoch 10/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0090
# Epoch 11/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0089
# Epoch 12/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0087
# Epoch 13/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0086
# Epoch 14/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0084
# Epoch 15/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0081
# Epoch 16/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0079
# Epoch 17/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0078
# Epoch 18/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0076
# Epoch 19/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0074
# Epoch 20/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0072
# Epoch 21/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0070
# Epoch 22/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0071
# Epoch 23/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0069
# Epoch 24/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0069
# Epoch 25/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0070
# Epoch 26/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0067
# Epoch 27/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0067
# Epoch 28/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0067
# Epoch 29/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0067
# Epoch 30/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0066
# Epoch 31/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0066
# Epoch 32/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0066
# Epoch 33/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0071
# Epoch 34/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0066
# Epoch 35/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0068
# Epoch 36/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0065
# Epoch 37/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0065
# Epoch 38/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0067
# Epoch 39/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0064
# Epoch 40/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0066
# Epoch 41/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0065
# Epoch 42/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0065
# Epoch 43/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0064
# Epoch 44/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0065
# Epoch 45/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0064
# Epoch 46/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0065
# Epoch 47/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0071
# Epoch 48/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0066
# Epoch 49/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0065
# Epoch 50/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0064
# Epoch 51/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0064
# Epoch 52/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0067
# Epoch 53/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0064
# Epoch 54/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0065
# Epoch 55/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0065
# Epoch 56/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0064
# Epoch 57/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 58/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0064
# Epoch 59/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0064
# Epoch 60/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0064
# Epoch 61/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0064
# Epoch 62/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 63/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 64/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 65/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0064
# Epoch 66/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 67/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0064
# Epoch 68/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 69/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 70/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0065
# Epoch 71/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0068
# Epoch 72/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 73/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0065
# Epoch 74/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0064
# Epoch 75/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 76/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 77/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 78/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0065
# Epoch 79/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 80/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 81/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 82/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0064
# Epoch 83/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 84/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0064
# Epoch 85/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0064
# Epoch 86/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 87/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 88/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0066
# Epoch 89/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 90/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 91/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 92/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 93/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0065
# Epoch 94/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 95/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 96/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 97/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 98/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 99/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 100/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 101/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 102/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 103/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 104/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 105/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 106/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 107/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 108/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 109/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0064
# Epoch 110/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0064
# Epoch 111/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 112/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0065
# Epoch 113/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 114/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0064
# Epoch 115/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 116/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 117/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 118/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 119/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 120/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0064
# Epoch 121/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 122/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 123/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0064
# Epoch 124/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 125/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 126/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 127/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 128/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 129/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 130/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 131/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 132/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 133/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0064
# Epoch 134/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 135/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 136/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 137/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 138/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 139/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 140/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 141/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 142/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 143/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 144/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 145/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 146/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 147/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 148/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 149/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 150/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0061
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 128)               70656
#
#  dense (Dense)               (None, 30)                3870
#
# =================================================================
# Total params: 74,526
# Trainable params: 74,526
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 预测
#train_predict = model.predict(x_train)
test_predict = model.predict(x_test) # 3个月的数据

# 前面把数据缩放到0-1范围。
# 现在跟实际值做比较，将预测值反标准化，从0-1范围转换为原数据范围
#train_predict = scaler.inverse_transform(train_predict)
#y_train = scaler.inverse_transform([y_train])

test_predict = scaler.inverse_transform(test_predict)
y_test = scaler.inverse_transform([y_test])

# 评估RMSE误差
score_rmse = np.sqrt(mean_squared_error(y_test[0], test_predict[:,1]))
score_mae = mean_absolute_error(y_test[0], test_predict[:,1])
print(Fore.GREEN + 'RMSE: {}'.format(score_rmse))
from sklearn.metrics import r2_score
print('R2-score:',r2_score(y_test[0], test_predict[:,1]))
# Out:
# RMSE: 270.571084419083
# R2-score: 0.5627665417732007

# %%
# 准备画图 - 训练数据
x_train_ticks = univariate_df.head(train_size)['ds']
y_train = univariate_df.head(train_size)['y']
x_test_ticks = univariate_df.tail(test_predict[:,0].size)['ds']

# 准备画图 - 测试数据
f, ax = plt.subplots(1)
f.set_figheight(6)
f.set_figwidth(15)

sns.lineplot(x=x_train_ticks[-30:], y=y_train[-30:], ax=ax, label='Train Set') #navajowhite
sns.lineplot(x=x_test_ticks, y=test_predict[:,0], ax=ax, color='green', label='Prediction') #navajowhite
sns.lineplot(x=x_test_ticks, y=y_test[0], ax=ax, color='orange', label='Ground truth') #navajowhite

ax.set_title(f'Prediction \n MAE: {score_mae:.2f}, RMSE: {score_rmse:.2f}', fontsize=14)
ax.set_xlabel(xlabel='Date', fontsize=14)
ax.set_ylabel(ylabel='有功功率最大值', fontsize=14)
plt.show()

# %%
day_index = pd.date_range(start='2021-06-03',end='2021-08-31',freq='D')
day_index = pd.DataFrame(day_index,columns=['date_day'])

test_predict = pd.DataFrame(test_predict[:,0],columns=['sum'])
test_predict = pd.concat((test_predict,day_index),axis=1)
test_predict.index = test_predict['date_day']

# %%
for i in range(test_predict['sum'].count()):
    if (test_predict.iloc[i,0] == test_predict['sum'].max()):
        print("\n最大值为：",test_predict.iloc[i,0])
        print("最大日期为：",test_predict.iloc[i,1])
    if (test_predict.iloc[i,0] == test_predict['sum'].min()):
        print("\n最小值为：",test_predict.iloc[i,0])
        print("最小日期为：",test_predict.iloc[i,1])
print(f'\nPrediction \n MAE: {score_mae:.2f}, RMSE: {score_rmse:.2f}')
# Out:
# 最小值为： 2215.9265
# 最小日期为： 2021-06-20 00:00:00
#
# 最大值为： 3650.0105
# 最大日期为： 2021-07-13 00:00:00
#
# Prediction
#  MAE: 208.37, RMSE: 270.57

# %% [markdown]
# ## LSTM非普工业最小功率三十天预测

# %%
test_size = 90  #预测测试值范围
train_size = len(df) - test_size  #预测训练值范围
df = df.fillna(0)
univariate_df = df[['date', '有功功率最小值（kw）']].copy()
univariate_df.columns = ['ds', 'y']


# LSTM对输入数据的大小敏感，需要对输入数据做标准化处理
# 使用MinMaxScaler将数据映射到0-1区间
from sklearn.preprocessing import MinMaxScaler
data = univariate_df.filter(['y'])
dataset = data.values
scaler = MinMaxScaler(feature_range=(-1, 0))
scaled_data = scaler.fit_transform(dataset)

scaled_data[-10:]
# Out:
# array([[-0.29615373],
#        [-0.28339042],
#        [-0.27065513],
#        [-0.24752979],
#        [-0.24337082],
#        [-0.25104234],
#        [-0.3167906 ],
#        [-0.24928465],
#        [-0.2415804 ],
#        [-0.25888254]])

# %%
def check(du):
    #正态检测
    u = du.mean()
    # 计算标准差
    std = du.std()
    # 计算P值
    res=kstest(du.astype(float),  'norm', (u, std))[1]
    print(res)
    # 判断p值是否服从正态分布，p<=0.05 则服从正态分布，否则不服从。
    if res<=0.05:
        print('该列数据服从正态分布------------')
        print('均值为：%.3f，标准差为：%.3f' % (u, std))
        print('------------------------------')
    else:
        print("错误")

def sta(sta_du):
    stas = []
    u = sta_du.mean()
    std = sta_du.std()
    for i in sta_du:
        stas.append((i-u)/(std*std))
    return stas

# %%
du_day_max = df['最高温度']
du_day_min = df['最低温度']

#温度标准化
from scipy.stats import kstest
check(du_day_max)
check(du_day_min)
du_day_max = sta(du_day_max)
du_day_min = sta(du_day_min)
# Out:
# 3.574350681268186e-05
# 该列数据服从正态分布------------
# 均值为：27.734，标准差为：6.059
# ------------------------------
# 1.8130741067440147e-12
# 该列数据服从正态分布------------
# 均值为：20.148，标准差为：6.031
# ------------------------------

# %%
f, ax = plt.subplots(nrows=1, ncols=1, figsize=(20, 6))
sns.distplot(du_day_min, ax=ax,color='green',label='du_day_max') #直方图和核密度图的结合，查看单个连续型变量的分布
sns.distplot(du_day_max, ax=ax, color='orange',label='du_day_min') #直方图和核密度图的结合，查看单个连续型变量的分布
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
du_day_max = list(map(list, zip(du_day_max)))
du_day_min = list(map(list, zip(du_day_min)))

# %%
look_back = 7 # 96
# 将数据分为训练集、测试集
train, test = scaled_data[:train_size-look_back,:], scaled_data[train_size-look_back:,:]

# 生成t-x数据
def create_dataset(dataset, look_back):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# 设置随机种子，保证复现

np.random.seed(7)


x_train, y_train = create_dataset(train, look_back)
x_test, y_test = create_dataset(test, look_back)

#添加特征列
x_train = np.append(x_train,du_day_max[0:train_size-look_back*2],axis=1)
x_train = np.append(x_train,du_day_min[0:train_size-look_back*2],axis=1)
x_test = np.append(x_test,du_day_max[train_size:],axis=1)
x_test = np.append(x_test,du_day_min[train_size:],axis=1)


# LSTM网络的输入为【批次大小(行数)，时间步长，特征数量(列数)】
# 将数据转换为符合输入的格式
x_train = np.reshape(x_train, (x_train.shape[0], 1, x_train.shape[1]))
x_test = np.reshape(x_test, (x_test.shape[0], 1, x_test.shape[1]))

print(len(x_train), len(x_test))
# Out:
# 587 90

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM

# 创建LSTM模型，拟合数据
model = Sequential()

# 添加128个LSTM神经元的隐层网络
model.add(LSTM(128, input_shape=(x_train.shape[1], x_train.shape[2]))) #return_sequences=True
#model.add(LSTM(64, return_sequences=False))
model.add(Dense(30))
#model.add(Dense(1))

# 损失函数与adam优化器
model.compile(optimizer='adam', loss='mean_squared_error')

# 训练数据10期, batch_size:一次训练抓取的样本数量
model.fit(x_train, y_train, batch_size=16, epochs=150 )  #validation_data=(x_test, y_test)

model.summary()
# Out:
# Epoch 1/150
# 37/37 [==============================] - 1s 2ms/step - loss: 0.1435
# Epoch 2/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0191
# Epoch 3/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0146
# Epoch 4/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0143
# Epoch 5/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0142
# Epoch 6/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0140
# Epoch 7/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0137
# Epoch 8/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0135
# Epoch 9/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0134
# Epoch 10/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0132
# Epoch 11/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0130
# Epoch 12/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0128
# Epoch 13/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0128
# Epoch 14/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0127
# Epoch 15/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0125
# Epoch 16/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0125
# Epoch 17/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0122
# Epoch 18/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0122
# Epoch 19/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0121
# Epoch 20/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0121
# Epoch 21/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0123
# Epoch 22/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0123
# Epoch 23/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0120
# Epoch 24/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0119
# Epoch 25/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0121
# Epoch 26/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0119
# Epoch 27/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0120
# Epoch 28/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0119
# Epoch 29/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0119
# Epoch 30/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0118
# Epoch 31/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0117
# Epoch 32/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0121
# Epoch 33/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0119
# Epoch 34/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0119
# Epoch 35/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0119
# Epoch 36/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0117
# Epoch 37/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0117
# Epoch 38/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0117
# Epoch 39/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0117
# Epoch 40/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0117
# Epoch 41/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0116
# Epoch 42/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0119
# Epoch 43/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0118
# Epoch 44/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0120
# Epoch 45/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0123
# Epoch 46/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0117
# Epoch 47/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0116
# Epoch 48/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0117
# Epoch 49/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0119
# Epoch 50/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0117
# Epoch 51/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0118
# Epoch 52/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0117
# Epoch 53/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0118
# Epoch 54/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0118
# Epoch 55/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0115
# Epoch 56/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0122
# Epoch 57/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0116
# Epoch 58/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0116
# Epoch 59/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0116
# Epoch 60/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0121
# Epoch 61/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0115
# Epoch 62/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0115
# Epoch 63/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0117
# Epoch 64/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0115
# Epoch 65/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0115
# Epoch 66/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0115
# Epoch 67/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0116
# Epoch 68/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0114
# Epoch 69/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0119
# Epoch 70/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0117
# Epoch 71/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0119
# Epoch 72/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0115
# Epoch 73/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0116
# Epoch 74/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0117
# Epoch 75/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0119
# Epoch 76/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0114
# Epoch 77/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0119
# Epoch 78/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0116
# Epoch 79/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0116
# Epoch 80/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0114
# Epoch 81/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0114
# Epoch 82/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0118
# Epoch 83/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0115
# Epoch 84/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0114
# Epoch 85/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0113
# Epoch 86/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0117
# Epoch 87/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0115
# Epoch 88/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0115
# Epoch 89/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0114
# Epoch 90/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0114
# Epoch 91/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0115
# Epoch 92/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0113
# Epoch 93/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0113
# Epoch 94/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0114
# Epoch 95/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0116
# Epoch 96/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0117
# Epoch 97/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0115
# Epoch 98/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0115
# Epoch 99/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0113
# Epoch 100/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0115
# Epoch 101/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0114
# Epoch 102/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0113
# Epoch 103/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0115
# Epoch 104/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0113
# Epoch 105/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0113
# Epoch 106/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0114
# Epoch 107/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0113
# Epoch 108/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0113
# Epoch 109/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0113
# Epoch 110/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0113
# Epoch 111/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0113
# Epoch 112/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0114
# Epoch 113/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0113
# Epoch 114/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0114
# Epoch 115/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0115
# Epoch 116/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0112
# Epoch 117/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0113
# Epoch 118/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0111
# Epoch 119/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0111
# Epoch 120/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0111
# Epoch 121/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0114
# Epoch 122/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0112
# Epoch 123/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0112
# Epoch 124/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0111
# Epoch 125/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0110
# Epoch 126/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0110
# Epoch 127/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0117
# Epoch 128/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0116
# Epoch 129/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0114
# Epoch 130/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0111
# Epoch 131/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0110
# Epoch 132/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0110
# Epoch 133/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0110
# Epoch 134/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0111
# Epoch 135/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0112
# Epoch 136/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0111
# Epoch 137/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0110
# Epoch 138/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0108
# Epoch 139/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0109
# Epoch 140/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0110
# Epoch 141/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0109
# Epoch 142/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0110
# Epoch 143/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0110
# Epoch 144/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0108
# Epoch 145/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0109
# Epoch 146/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0109
# Epoch 147/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0108
# Epoch 148/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0108
# Epoch 149/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0111
# Epoch 150/150
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0112
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 128)               70656
#
#  dense_1 (Dense)             (None, 30)                3870
#
# =================================================================
# Total params: 74,526
# Trainable params: 74,526
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 预测
#train_predict = model.predict(x_train)
test_predict = model.predict(x_test) # 3个月的数据

# 前面把数据缩放到0-1范围。
# 现在跟实际值做比较，将预测值反标准化，从0-1范围转换为原数据范围
#train_predict = scaler.inverse_transform(train_predict)
#y_train = scaler.inverse_transform([y_train])

test_predict = scaler.inverse_transform(test_predict)
y_test = scaler.inverse_transform([y_test])

# 评估RMSE误差
score_rmse = np.sqrt(mean_squared_error(y_test[0], test_predict[:,1]))
score_mae = mean_absolute_error(y_test[0], test_predict[:,1])
print(Fore.GREEN + 'RMSE: {}'.format(score_rmse))
from sklearn.metrics import r2_score
print('R2-score:',r2_score(y_test[0], test_predict[:,1]))
# Out:
# RMSE: 200.66198761039286
# R2-score: -0.20716157710208738

# %%
# 准备画图 - 训练数据
x_train_ticks = univariate_df.head(train_size)['ds']
y_train = univariate_df.head(train_size)['y']
x_test_ticks = univariate_df.tail(test_predict[:,0].size)['ds']

# 准备画图 - 测试数据
f, ax = plt.subplots(1)
f.set_figheight(6)
f.set_figwidth(15)

sns.lineplot(x=x_train_ticks[-30:], y=y_train[-30:], ax=ax, label='Train Set') #navajowhite
sns.lineplot(x=x_test_ticks, y=test_predict[:,0], ax=ax, color='green', label='Prediction') #navajowhite
sns.lineplot(x=x_test_ticks, y=y_test[0], ax=ax, color='orange', label='Ground truth') #navajowhite

ax.set_title(f'Prediction \n MAE: {score_mae:.2f}, RMSE: {score_rmse:.2f}', fontsize=14)
ax.set_xlabel(xlabel='Date', fontsize=14)
ax.set_ylabel(ylabel='有功功率最大值', fontsize=14)
plt.show()

# %%
day_index = pd.date_range(start='2021-06-03',end='2021-08-31',freq='D')
day_index = pd.DataFrame(day_index,columns=['date_day'])

test_predict = pd.DataFrame(test_predict[:,0],columns=['sum'])
test_predict = pd.concat((test_predict,day_index),axis=1)
test_predict.index = test_predict['date_day']

# %%
for i in range(test_predict['sum'].count()):
    if (test_predict.iloc[i,0] == test_predict['sum'].max()):
        print("\n最大值为：",test_predict.iloc[i,0])
        print("最大日期为：",test_predict.iloc[i,1])
    if (test_predict.iloc[i,0] == test_predict['sum'].min()):
        print("\n最小值为：",test_predict.iloc[i,0])
        print("最小日期为：",test_predict.iloc[i,1])
print(f'\nPrediction \n MAE: {score_mae:.2f}, RMSE: {score_rmse:.2f}')
# Out:
# 最小值为： 972.232
# 最小日期为： 2021-06-04 00:00:00
#
# 最大值为： 1487.8326
# 最大日期为： 2021-07-08 00:00:00
#
# Prediction
#  MAE: 161.51, RMSE: 200.66
