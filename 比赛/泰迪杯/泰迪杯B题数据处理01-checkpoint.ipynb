# %%
import seaborn as sns   #读取数据
import pandas as pd
# %matplotlib  inline
y = pd.read_csv('./附件1-区域15分钟负荷数据.csv')
indu = pd.read_csv('./附件2-行业日负荷数据.csv')
tianqi = pd.read_csv('./附件3-气象数据.csv')
tianqi = tianqi.drop([0],axis=0)
tianqi
# Out:
#               日期     天气状况 最高温度 最低温度    白天风力风向    夜晚风力风向
# 1      2018年1月1日    多云/多云  22℃  12℃  无持续风向<3级  无持续风向<3级
# 2      2018年1月2日    多云/多云  22℃  15℃  无持续风向<3级  无持续风向<3级
# 3      2018年1月3日     多云/阴  23℃  15℃  无持续风向<3级  无持续风向<3级
# 4      2018年1月4日    多云/小雨  21℃  16℃  无持续风向<3级  无持续风向<3级
# 5      2018年1月5日     阴/小雨  19℃  13℃  无持续风向<3级  无持续风向<3级
# ...          ...      ...  ...  ...       ...       ...
# 1340  2021年8月27日  雷阵雨/雷阵雨  35℃  26℃    北风1-2级    北风1-2级
# 1341  2021年8月28日   雷阵雨/多云  33℃  26℃    北风1-2级    北风1-2级
# 1342  2021年8月29日  雷阵雨/雷阵雨  32℃  25℃    北风1-2级    北风1-2级
# 1343  2021年8月30日    阵雨/阵雨  34℃  26℃    北风1-2级    北风1-2级
# 1344  2021年8月31日   雷阵雨/阵雨  32℃  26℃    北风1-2级    北风1-2级
#
# [1344 rows x 6 columns]

# %%
#del tianqi['Unnamed: 6']  #删除Unnamed：6

# %%
tianqi['最高温度'] = tianqi['最高温度'].map(lambda d: d.replace('℃','')).astype(int)  #使用空格替换摄氏度
tianqi['最低温度'] = tianqi['最低温度'].map(lambda d: d.replace('℃','')).astype(int)

# %%
series = tianqi.join(tianqi['天气状况'].str.split('/',expand=True))  #以/切割天气状况并且分配给天气1与天气2
tianqi['天气1'] = series[0]
tianqi['天气2'] = series[1]
tianqi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1344 entries, 1 to 1344
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   日期      1344 non-null   object
#  1   天气状况    1344 non-null   object
#  2   最高温度    1344 non-null   int32
#  3   最低温度    1344 non-null   int32
#  4   白天风力风向  1344 non-null   object
#  5   夜晚风力风向  1344 non-null   object
#  6   天气1     1344 non-null   object
#  7   天气2     1344 non-null   object
# dtypes: int32(2), object(6)
# memory usage: 116.3+ KB

# %%
tianqi['白天风力风向'].unique()  #去重
# Out:
# array(['无持续风向<3级', '北风4～5级', '微风<3级', '北风3', '东北风3～4级', '北风3～4级',
#        '南风3～4级', '南风4～5级', '东北偏东风2', '无持续风向微风', '无持续风向1-2级', '东风3-4级',
#        '东南风4-5级', '东风3～4级', '东北风3-4级', '东风8-9级', '东南风3-4级', '北风3-4级',
#        '北风4-5级', '南风3-4级', '南风1-2级', '东南风1-2级', '西南风3-4级', '东风1-2级',
#        '北风1-2级', '东北风1-2级', '西南风1-2级'], dtype=object)

# %%
tianqi['夜晚风力风向'].unique()
# Out:
# array(['无持续风向<3级', '北风4～5级', '北风3～4级', '微风<3级', '北风3', '东北偏东风2',
#        '无持续风向微风', '无持续风向1-2级', '东风3-4级', '东南风4-5级', '东南风3～4级', '东北风3-4级',
#        '东风8-9级', '东南风3-4级', '北风3-4级', '北风4-5级', '南风3-4级', '南风1-2级',
#        '东南风1-2级', '西南风3-4级', '东风1-2级', '北风1-2级', '东北风1-2级', '西南风1-2级'],
#       dtype=object)

# %%
dic = { '无持续风向微风':0, 
        '无持续风向1-2级':1,        
        '东南风1-2级':1,
        '南风1-2级':1,
        '东风1-2级':1,
        '北风1-2级':1,
        '东北风1-2级':1,
        '西南风1-2级':1,
        '东北偏东风2':2, 
        '微风<3级':3, 
        '无持续风向<3级':3,
        '北风3':4,
        '东北风3～4级':5, 
        '东南风3-4级':5,
        '东南风3～4级':5,
        '东风3-4级':5,
        '北风3～4级':5,
        '南风3～4级':5, 
        '南风3-4级':5, 
        '东风3～4级':5, 
        '西南风3-4级':5,
        '东北风3-4级':5, 
        '北风3-4级':5,
        '北风4-5级':6, 
        '北风4～5级':6,
        '南风4～5级':6,
        '东南风4-5级':6, 
        '东风8-9级':7,}  #使用字典映射
tianqi['白天风力风向'] = tianqi['白天风力风向'].map(dic)
tianqi['夜晚风力风向'] = tianqi['夜晚风力风向'].map(dic)

# %%
tianqi
# Out:
#               日期     天气状况  最高温度  最低温度  白天风力风向  夜晚风力风向  天气1  天气2
# 1      2018年1月1日    多云/多云    22    12       3       3   多云   多云
# 2      2018年1月2日    多云/多云    22    15       3       3   多云   多云
# 3      2018年1月3日     多云/阴    23    15       3       3   多云    阴
# 4      2018年1月4日    多云/小雨    21    16       3       3   多云   小雨
# 5      2018年1月5日     阴/小雨    19    13       3       3    阴   小雨
# ...          ...      ...   ...   ...     ...     ...  ...  ...
# 1340  2021年8月27日  雷阵雨/雷阵雨    35    26       1       1  雷阵雨  雷阵雨
# 1341  2021年8月28日   雷阵雨/多云    33    26       1       1  雷阵雨   多云
# 1342  2021年8月29日  雷阵雨/雷阵雨    32    25       1       1  雷阵雨  雷阵雨
# 1343  2021年8月30日    阵雨/阵雨    34    26       1       1   阵雨   阵雨
# 1344  2021年8月31日   雷阵雨/阵雨    32    26       1       1  雷阵雨   阵雨
#
# [1344 rows x 8 columns]

# %%
tianqi['天气1'].unique()  #去重
# Out:
# array(['多云', '阴', '小雨-中雨', '大雨', '中雨', '小雨', '晴', '雷阵雨', '雾', '阵雨',
#        '中雨-大雨', '晴间多云', '暴雨', '小到中雨', '中到大雨', '大到暴雨'], dtype=object)

# %%
tianqi['天气2'].unique()
# Out:
# array(['多云', '阴', '小雨', '中雨-大雨', '中雨', '小雨-中雨', '晴', '局部多云', '阵雨', '雾',
#        '雷阵雨', '大雨', '暴雨', '中到大雨', '小到中雨', '大到暴雨'], dtype=object)

# %%
dic1 = { '晴':0, 
         '晴间多云':1,
         '局部多云':2，
         '多云':3,
         '雾':4,
         '阴':5, 
         '阵雨':6,
         '雷阵雨':7,
         '小雨':8,
         '小到中雨':9,
         '小雨-中雨':10, 
         '中雨':11,
         '中雨-大雨':12,
         '大雨':13,
         '大到暴雨':14,
         '暴雨':15
       }
tianqi['天气1'] = tianqi['天气1'].map(dic1)  #使用去重后数据映射
tianqi['天气2'] = tianqi['天气2'].map(dic1)
del tianqi['天气状况']

# %%
tianqi
# Out:
#               日期  最高温度  最低温度  白天风力风向  夜晚风力风向  天气1  天气2
# 1      2018年1月1日    22    12     0.0     0.0  2.0  2.0
# 2      2018年1月2日    22    15     0.0     0.0  2.0  2.0
# 3      2018年1月3日    23    15     0.0     0.0  2.0  3.0
# 4      2018年1月4日    21    16     0.0     0.0  2.0  4.0
# 5      2018年1月5日    19    13     0.0     0.0  3.0  4.0
# ...          ...   ...   ...     ...     ...  ...  ...
# 1340  2021年8月27日    35    26     NaN     NaN  NaN  NaN
# 1341  2021年8月28日    33    26     NaN     NaN  NaN  2.0
# 1342  2021年8月29日    32    25     NaN     NaN  NaN  NaN
# 1343  2021年8月30日    34    26     NaN     NaN  NaN  NaN
# 1344  2021年8月31日    32    26     NaN     NaN  NaN  NaN
#
# [1344 rows x 7 columns]

# %%
y = y.rename(columns={'数据时间':'日期1'})  #更改列名称
y['日期'] = y['日期1'].apply(lambda x: x.split(' ')[0])  #使用split分隔日期，把年月日赋值给日期
tianqi.loc[:, '日期'] = pd.to_datetime(tianqi.loc[:, '日期'], format='%Y年%m月%d日', errors='coerce')  #将日期规格化
y.loc[:, '日期'] = pd.to_datetime(y.loc[:, '日期'], format='%Y/%m/%d', errors='coerce') #将日期规格化
train = y.merge(tianqi,on='日期',how='left')  #将y表与tianqi表合并
del train['日期']  #删除日期列

# %%
train.to_csv("泰迪杯数据01.csv",index=False,encoding='utf_8_sig')  #将数据写入

# %%
train
# Out:
#                        日期1    总有功功率（kw）  最高温度  最低温度  白天风力风向  夜晚风力风向  天气1  天气2
# 0        2018/1/1 00:00:00  244033.7682    22    12     0.0     0.0  2.0  2.0
# 1        2018/1/1 00:15:00  232720.6402    22    12     0.0     0.0  2.0  2.0
# 2        2018/1/1 00:30:00  231685.6891    22    12     0.0     0.0  2.0  2.0
# 3        2018/1/1 00:45:00  227581.3317    22    12     0.0     0.0  2.0  2.0
# 4        2018/1/1 01:00:00  233482.4269    22    12     0.0     0.0  2.0  2.0
# ...                    ...          ...   ...   ...     ...     ...  ...  ...
# 128631  2021/8/31 22:45:00  202409.1270    32    26     NaN     NaN  NaN  NaN
# 128632  2021/8/31 23:00:00  218576.4635    32    26     NaN     NaN  NaN  NaN
# 128633  2021/8/31 23:15:00  200112.5091    32    26     NaN     NaN  NaN  NaN
# 128634  2021/8/31 23:30:00  199865.5937    32    26     NaN     NaN  NaN  NaN
# 128635  2021/8/31 23:45:00  198483.5592    32    26     NaN     NaN  NaN  NaN
#
# [128636 rows x 8 columns]
