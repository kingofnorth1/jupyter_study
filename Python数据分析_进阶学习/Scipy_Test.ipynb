# %%
import pandas as pd;
import numpy as np
import scipy
from scipy import integrate
import matplotlib.pyplot as plt;

# %%
x2 = lambda x: x**2
temp = integrate.quad(x2, 0, 4)
print(temp)
# Out:
# (21.333333333333336, 2.368475785867001e-13)

# %%
x = np.linspace(0, 100, 10)
y = map(lambda n: n**2, x)
plt.plot(x,list(y))

# %%
a = np.linspace(0, 20, 10)
a[0:1]
a.size
arr = np.array([2, 1, 5, 3, 7, 4, 6, 8])
np.sort(arr)
x = np.array([[1, 2], [3, 4]])
y = np.array([[5, 6]])
concat = np.concatenate((x,y),axis= 0)
concat.shape
concat.reshape(2,3)
a2 = np.expand_dims(a, axis=1)
a2[a2 > 10]
a2[(a2>=10)&(a2<=15)]
b1 = a2[0,:]
b1[0] = 99
a = a+a
a2[0:2, 0]
a2.max()
a2.sum(axis=0)
# Out:
# array([199.])

# %%
np.ones(3)
np.zeros(3)
np.random.random((3,2))
# np.integer(5, size=(2, 4)) 
b = np.array([11, 11, 12, 13, 14, 15, 16, 17, 12, 13, 11, 14, 18, 19, 20])
np.unique(b)
concat.transpose()
np.flip(b)
np.flip(concat, axis=1)
concat.flatten()
np.save('filename', concat)
np.load('filename.npy')
np.savetxt('new_file.csv', concat)
np.loadtxt('new_file.csv')
# Out:
# array([[1., 2.],
#        [3., 4.],
#        [5., 6.]])

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
X = np.arange(-5, 5, 0.15)
Y = np.arange(-5, 5, 0.15)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='viridis')
