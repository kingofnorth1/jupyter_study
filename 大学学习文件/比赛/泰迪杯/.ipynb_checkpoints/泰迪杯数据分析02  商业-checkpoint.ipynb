# %%
import numpy as np
import pandas as pd
from pandas import  DataFrame

import seaborn as sns 
import matplotlib.pyplot as plt 
from colorama import Fore

from sklearn.metrics import mean_absolute_error, mean_squared_error
import math

import warnings # Supress warnings 
warnings.filterwarnings('ignore')
plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号
np.random.seed(7)

df = pd.read_csv(r"./泰迪杯数据01_商业.csv")
df
# Out:
#     行业类型         日期1  有功功率最大值（kw）  有功功率最小值（kw）  最高温度  最低温度  白天风力风向  夜晚风力风向  \
# 0     商业  2019-01-01   64027.8582   23758.7970    12     7       1       1
# 1     商业  2019-01-02   75467.2143   20231.6265    11     6       1       1
# 2     商业  2019-01-03  132776.9442   20443.6182    15     9       1       1
# 3     商业  2019-01-04   97731.1308   19858.1592    17    12       1       1
# 4     商业  2019-01-05  132883.1868   19766.6994    17    12       1       1
# ..   ...         ...          ...          ...   ...   ...     ...     ...
# 973   商业  2021-08-27  104728.8762   19815.7638    35    26       1       1
# 974   商业  2021-08-28   93855.1368   20820.2490    33    26       1       1
# 975   商业  2021-08-29   84127.1658   21679.5828    32    25       1       1
# 976   商业  2021-08-30  102851.2758   21036.5868    34    26       1       1
# 977   商业  2021-08-31   96396.2568   21291.3042    32    26       1       1
#
#      天气1  天气2
# 0    5.0  5.0
# 1    8.0  8.0
# 2    3.0  8.0
# 3    5.0  8.0
# 4    5.0  8.0
# ..   ...  ...
# 973  7.0  7.0
# 974  7.0  3.0
# 975  7.0  7.0
# 976  6.0  6.0
# 977  7.0  6.0
#
# [978 rows x 10 columns]

# %%
df.columns
df  = df.rename(columns={'日期1':'date'}) #将日期1改为date

# %%
from datetime import datetime, date 

df['date'] = pd.to_datetime(df['date'])
df.head().style.set_properties(subset=['date'], **{'background-color': 'dodgerblue'}) #将date变为蓝色
# Out:
# <style type="text/css">
# #T_9dd4d_row0_col1, #T_9dd4d_row1_col1, #T_9dd4d_row2_col1, #T_9dd4d_row3_col1, #T_9dd4d_row4_col1 {
#   background-color: dodgerblue;
# }
# </style>
# <table id="T_9dd4d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >行业类型</th>
#       <th class="col_heading level0 col1" >date</th>
#       <th class="col_heading level0 col2" >有功功率最大值（kw）</th>
#       <th class="col_heading level0 col3" >有功功率最小值（kw）</th>
#       <th class="col_heading level0 col4" >最高温度</th>
#       <th class="col_heading level0 col5" >最低温度</th>
#       <th class="col_heading level0 col6" >白天风力风向</th>
#       <th class="col_heading level0 col7" >夜晚风力风向</th>
#       <th class="col_heading level0 col8" >天气1</th>
#       <th class="col_heading level0 col9" >天气2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9dd4d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9dd4d_row0_col0" class="data row0 col0" >商业</td>
#       <td id="T_9dd4d_row0_col1" class="data row0 col1" >2019-01-01 00:00:00</td>
#       <td id="T_9dd4d_row0_col2" class="data row0 col2" >64027.858200</td>
#       <td id="T_9dd4d_row0_col3" class="data row0 col3" >23758.797000</td>
#       <td id="T_9dd4d_row0_col4" class="data row0 col4" >12</td>
#       <td id="T_9dd4d_row0_col5" class="data row0 col5" >7</td>
#       <td id="T_9dd4d_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_9dd4d_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_9dd4d_row0_col8" class="data row0 col8" >5.000000</td>
#       <td id="T_9dd4d_row0_col9" class="data row0 col9" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9dd4d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9dd4d_row1_col0" class="data row1 col0" >商业</td>
#       <td id="T_9dd4d_row1_col1" class="data row1 col1" >2019-01-02 00:00:00</td>
#       <td id="T_9dd4d_row1_col2" class="data row1 col2" >75467.214300</td>
#       <td id="T_9dd4d_row1_col3" class="data row1 col3" >20231.626500</td>
#       <td id="T_9dd4d_row1_col4" class="data row1 col4" >11</td>
#       <td id="T_9dd4d_row1_col5" class="data row1 col5" >6</td>
#       <td id="T_9dd4d_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_9dd4d_row1_col7" class="data row1 col7" >1</td>
#       <td id="T_9dd4d_row1_col8" class="data row1 col8" >8.000000</td>
#       <td id="T_9dd4d_row1_col9" class="data row1 col9" >8.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9dd4d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9dd4d_row2_col0" class="data row2 col0" >商业</td>
#       <td id="T_9dd4d_row2_col1" class="data row2 col1" >2019-01-03 00:00:00</td>
#       <td id="T_9dd4d_row2_col2" class="data row2 col2" >132776.944200</td>
#       <td id="T_9dd4d_row2_col3" class="data row2 col3" >20443.618200</td>
#       <td id="T_9dd4d_row2_col4" class="data row2 col4" >15</td>
#       <td id="T_9dd4d_row2_col5" class="data row2 col5" >9</td>
#       <td id="T_9dd4d_row2_col6" class="data row2 col6" >1</td>
#       <td id="T_9dd4d_row2_col7" class="data row2 col7" >1</td>
#       <td id="T_9dd4d_row2_col8" class="data row2 col8" >3.000000</td>
#       <td id="T_9dd4d_row2_col9" class="data row2 col9" >8.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9dd4d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9dd4d_row3_col0" class="data row3 col0" >商业</td>
#       <td id="T_9dd4d_row3_col1" class="data row3 col1" >2019-01-04 00:00:00</td>
#       <td id="T_9dd4d_row3_col2" class="data row3 col2" >97731.130800</td>
#       <td id="T_9dd4d_row3_col3" class="data row3 col3" >19858.159200</td>
#       <td id="T_9dd4d_row3_col4" class="data row3 col4" >17</td>
#       <td id="T_9dd4d_row3_col5" class="data row3 col5" >12</td>
#       <td id="T_9dd4d_row3_col6" class="data row3 col6" >1</td>
#       <td id="T_9dd4d_row3_col7" class="data row3 col7" >1</td>
#       <td id="T_9dd4d_row3_col8" class="data row3 col8" >5.000000</td>
#       <td id="T_9dd4d_row3_col9" class="data row3 col9" >8.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9dd4d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9dd4d_row4_col0" class="data row4 col0" >商业</td>
#       <td id="T_9dd4d_row4_col1" class="data row4 col1" >2019-01-05 00:00:00</td>
#       <td id="T_9dd4d_row4_col2" class="data row4 col2" >132883.186800</td>
#       <td id="T_9dd4d_row4_col3" class="data row4 col3" >19766.699400</td>
#       <td id="T_9dd4d_row4_col4" class="data row4 col4" >17</td>
#       <td id="T_9dd4d_row4_col5" class="data row4 col5" >12</td>
#       <td id="T_9dd4d_row4_col6" class="data row4 col6" >1</td>
#       <td id="T_9dd4d_row4_col7" class="data row4 col7" >1</td>
#       <td id="T_9dd4d_row4_col8" class="data row4 col8" >5.000000</td>
#       <td id="T_9dd4d_row4_col9" class="data row4 col9" >8.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.isna().sum()
# Out:
# 行业类型            0
# date            0
# 有功功率最大值（kw）     0
# 有功功率最小值（kw）     0
# 最高温度            0
# 最低温度            0
# 白天风力风向          0
# 夜晚风力风向          0
# 天气1            10
# 天气2             3
# dtype: int64

# %%
df = df.fillna(method='ffill',axis=0)

# %%
df.drop('date', axis=1).columns
# Out:
# Index(['行业类型', '有功功率最大值（kw）', '有功功率最小值（kw）', '最高温度', '最低温度', '白天风力风向',
#        '夜晚风力风向', '天气1', '天气2'],
#       dtype='object')

# %%
# To compelte the data, as naive method, we will use ffill
f, ax = plt.subplots(nrows=9, ncols=1, figsize=(15, 25))

for i, column in enumerate(df.drop('date', axis=1).columns):  #enumerate将组成一个遍历序列
    sns.lineplot(x=df['date'], y=df[column].fillna(method='ffill'), ax=ax[i], color='dodgerblue')  #lineplot方法画图
    ax[i].set_title('Feature: {}'.format(column), fontsize=14) #显示标题
    ax[i].set_ylabel(ylabel=column, fontsize=14) #显示y轴变量

#     ax[i].set_xlim([date(2019, 1, 1), date(2021, 8, 31)]) #设置x轴的范围

# %%
#补缺失值
df['有功功率最大值（kw）'] = df['有功功率最大值（kw）'].interpolate()
df['有功功率最小值（kw）'] = df['有功功率最小值（kw）'].interpolate()
df.index = df['date']

# %% [markdown]
# ## 4 数据平滑与采样

# %%
# 行重复删除
df[df.index.duplicated()]
df = df[~df.index.duplicated()]

# %%
fig, ax = plt.subplots(nrows=3,ncols=1, sharex=True, figsize=(16,12))

sns.lineplot(x=df['date'],y=df['有功功率最大值（kw）'],ax=ax[0])
ax[0].set_title('有功功率最大值（kw） Volume')
ax[0].set_ylabel(ylabel='总有功率',fontsize=14)

ts = df['有功功率最大值（kw）'].resample('W',closed='left').mean()
sns.lineplot(x=df['date'],y=ts,ax=ax[1])
ax[1].set_title('Weekly 有功功率最大值（kw） Volume')
ax[1].set_ylabel(ylabel='有功功率最大值（kw）',fontsize=14)

ts = df['有功功率最大值（kw）'].resample('M',closed='left').mean()
sns.lineplot(x=df['date'],y=ts,ax=ax[2])
ax[2].set_title('Monthly 有功功率最大值（kw） Volume')
ax[2].set_ylabel(ylabel='有功功率最大值（kw）',fontsize=14)


for i in range(3):
#     ax[i].set_xlim([date(2019,1,1),date(2021,8,31)])
    plt.show()

# %%
fig, ax = plt.subplots(nrows=3,ncols=1, sharex=True, figsize=(16,12))

sns.lineplot(x=df['date'],y=df['有功功率最小值（kw）'],ax=ax[0])
ax[0].set_title('有功功率最小值（kw） Volume')
ax[0].set_ylabel(ylabel='总有功率',fontsize=14)

ts = df['有功功率最小值（kw）'].resample('W',closed='left').mean()
sns.lineplot(x=df['date'],y=ts,ax=ax[1])
ax[1].set_title('Weekly 有功功率最小值（kw） Volume')
ax[1].set_ylabel(ylabel='有功功率最小值（kw）',fontsize=14)

ts = df['有功功率最小值（kw）'].resample('M',closed='left').mean()
sns.lineplot(x=df['date'],y=ts,ax=ax[2])
ax[2].set_title('Monthly 有功功率最小值（kw） Volume')
ax[2].set_ylabel(ylabel='有功功率最小值（kw）',fontsize=14)


for i in range(3):
#     ax[i].set_xlim([date(2019,1,1),date(2021,8,31)])
    plt.show()

# %% [markdown]
# ## 5 平稳性检验

# %%
rolling_window = 52
f, ax = plt.subplots(nrows=1, ncols=1, figsize=(15, 8))

ts = df['有功功率最大值（kw）'].resample('W',closed='left').mean()
ts1 = df['有功功率最大值（kw）'].resample('W',closed='left').std()
sns.lineplot(x=df['date'],y=df['有功功率最大值（kw）'],ax=ax)
sns.lineplot(x=df['date'],y=ts,ax=ax,label='mean')
sns.lineplot(x=df['date'],y=ts1,ax=ax,label='std')
ax.set_ylabel(ylabel='有功功率最大值（kw） Volume', fontsize=14)
# ax.set_xlim([date(2019, 1, 1), date(2021, 8, 31)])
plt.tight_layout()
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller

result = adfuller(df['有功功率最大值（kw）'].values)
result
#p值小于0.05，第一个值比第五个值小，趋势平稳
# Out:
# (-1.9819889372990624,
#  0.2945257280892172,
#  8,
#  964,
#  {'1%': -3.437151658028634,
#   '5%': -2.8645428373470563,
#   '10%': -2.5683688733406793},
#  21265.284668943645)

# %%
# Thanks to https://www.kaggle.com/iamleonie for this function!
f, ax = plt.subplots(nrows=1, ncols=1, figsize=(12, 6))

def visualize_adfuller_results(series, title, ax):
    sns.lineplot(x=df['date'],y=series,ax=ax)
    ax.set_title(result)
    ax.set_ylabel(title)
#     ax.set_xlim([date(2019, 1, 1), date(2021, 8, 31)])

visualize_adfuller_results(df['有功功率最大值（kw）'].values, '有功功率最大值（kw）',ax=ax)
# visualize_adfuller_results(df['temperature'].values, 'Temperature', ax[1, 0])
# visualize_adfuller_results(df['river_hydrometry'].values, 'River_Hydrometry', ax[0, 1])
# visualize_adfuller_results(df['drainage_volume'].values, 'Drainage_Volume', ax[1, 1])
# visualize_adfuller_results(df['depth_to_groundwater'].values, 'Depth_to_Groundwater', ax[2, 0])

# f.delaxes(ax[2, 1])
plt.tight_layout()
plt.show()

# %%
rolling_window = 52
f, ax = plt.subplots(nrows=1, ncols=1, figsize=(15, 8))

ts = df['有功功率最小值（kw）'].resample('W',closed='left').mean()
ts1 = df['有功功率最小值（kw）'].resample('W',closed='left').std()
sns.lineplot(x=df['date'],y=df['有功功率最小值（kw）'],ax=ax)
sns.lineplot(x=df['date'],y=ts,ax=ax,label='mean')
sns.lineplot(x=df['date'],y=ts1,ax=ax,label='std')
ax.set_ylabel(ylabel='有功功率最小值（kw） Volume', fontsize=14)
# ax.set_xlim([date(2019, 1, 1), date(2021, 8, 31)])
plt.tight_layout()
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller

result = adfuller(df['有功功率最小值（kw）'].values)
result
#p值小于0.05，第一个值比第五个值小，趋势平稳
# Out:
# (-3.6350775630310124,
#  0.005124764307532995,
#  9,
#  963,
#  {'1%': -3.4371587399783072,
#   '5%': -2.8645459603872903,
#   '10%': -2.568370536787406},
#  18066.870903451072)

# %%
# Thanks to https://www.kaggle.com/iamleonie for this function!
f, ax = plt.subplots(nrows=1, ncols=1, figsize=(12, 6))

def visualize_adfuller_results(series, title, ax):
    sns.lineplot(x=df['date'],y=series,ax=ax)
    ax.set_title(result)
    ax.set_ylabel(title)
    ax.set_xlim([date(2019, 1, 1), date(2021, 8, 31)])

visualize_adfuller_results(df['有功功率最小值（kw）'].values, '有功功率最小值（kw）',ax=ax)
# visualize_adfuller_results(df['temperature'].values, 'Temperature', ax[1, 0])
# visualize_adfuller_results(df['river_hydrometry'].values, 'River_Hydrometry', ax[0, 1])
# visualize_adfuller_results(df['drainage_volume'].values, 'Drainage_Volume', ax[1, 1])
# visualize_adfuller_results(df['depth_to_groundwater'].values, 'Depth_to_Groundwater', ax[2, 0])

# f.delaxes(ax[2, 1])
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 异常值处理

# %%
from scipy.stats import kstest
#正态检测
u = df['有功功率最大值（kw）'].mean()
# 计算标准差
std = df['有功功率最大值（kw）'].std()
# 计算P值
res=kstest(df['有功功率最大值（kw）'].astype(float),  'norm', (u, std))[1]
print(res)
# 判断p值是否服从正态分布，p<=0.05 则服从正态分布，否则不服从。
if res<=0.05:
    print('该列数据服从正态分布------------')
    print('均值为：%.3f，标准差为：%.3f' % (u, std))
    print('------------------------------')
else:
    print("错误")

#KS检验3σ异常点检测
sum =[]
# 计算均值
u = df['有功功率最大值（kw）'].mean()
# 计算标准差
std = df['有功功率最大值（kw）'].std()
# 定义3σ法则识别异常值
# 识别异常值
error = df['有功功率最大值（kw）'][np.abs(df['有功功率最大值（kw）'] - u) > 3 * std]
df.loc[error.index,'总有功功率（kw）'] = np.nan
# 剔除异常值，保留正常的数据
data_c = df['有功功率最大值（kw）'][np.abs(df['有功功率最大值（kw）'] - u) <= 3 * std]
# 输出异常数据
sum.append(error)
# print(error)
# Out:
# 2.9859732319727065e-09
# 该列数据服从正态分布------------
# 均值为：95203.802，标准差为：50029.947
# ------------------------------

# %%
df = df.fillna(method='ffill',axis=0)  #异常处理

f, ax = plt.subplots(nrows=1, ncols=1, figsize=(15, 6))
visualize_adfuller_results(df['有功功率最大值（kw）'],'df' , ax=ax)

# %%
from scipy.stats import kstest
#正态检测
u = df['有功功率最小值（kw）'].mean()
# 计算标准差
std = df['有功功率最小值（kw）'].std()
# 计算P值
res=kstest(df['有功功率最小值（kw）'].astype(float),  'norm', (u, std))[1]
print(res)
# 判断p值是否服从正态分布，p<=0.05 则服从正态分布，否则不服从。
if res<=0.05:
    print('该列数据服从正态分布------------')
    print('均值为：%.3f，标准差为：%.3f' % (u, std))
    print('------------------------------')
else:
    print("错误")

#KS检验3σ异常点检测
sum =[]
# 计算均值
u = df['有功功率最小值（kw）'].mean()
# 计算标准差
std = df['有功功率最小值（kw）'].std()
# 定义3σ法则识别异常值
# 识别异常值
error = df['有功功率最小值（kw）'][np.abs(df['有功功率最小值（kw）'] - u) > 3 * std]
df.loc[error.index,'总有功功率（kw）'] = np.nan
# 剔除异常值，保留正常的数据
data_c = df['有功功率最小值（kw）'][np.abs(df['有功功率最小值（kw）'] - u) <= 3 * std]
# 输出异常数据
sum.append(error)
# print(error)
# Out:
# 0.01207741109084104
# 该列数据服从正态分布------------
# 均值为：16682.965，标准差为：4988.073
# ------------------------------

# %%
df = df.fillna(method='ffill',axis=0)  #异常处理

f, ax = plt.subplots(nrows=1, ncols=1, figsize=(15, 6))
visualize_adfuller_results(df['有功功率最小值（kw）'],'df' , ax=ax)

# %%
df['有功功率最大值（kw）'] = df['有功功率最大值（kw）'].astype(float)
df['有功功率最小值（kw）'] = df['有功功率最小值（kw）'].astype(float)
df['最高温度'] = df['最高温度'].astype(float)
df['最低温度'] = df['最低温度'].astype(float)
df['白天风力风向'] = df['白天风力风向'].astype(float)
df['夜晚风力风向'] = df['夜晚风力风向'].astype(float)
df['天气1'] = df['天气1'].astype(float)
df['天气2'] = df['天气2'].astype(float)

# %%
f, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 8))

shifted_cols = df.columns[1:9]
corrmat = df[shifted_cols].corr()  #输出函数的相关性

sns.heatmap(corrmat, annot=True, vmin=-1, vmax=1, cmap='coolwarm_r')  #画出相关性的热力图
ax.set_title('Correlation Matrix of Lagged Features', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix of Lagged Features')

# %% [markdown]
# ## LSTM商业最大功率三十天预测

# %%
test_size = 90  #预测测试值范围
train_size = len(df) - test_size  #预测训练值范围
df = df.fillna(0)
univariate_df = df[['date', '有功功率最大值（kw）']].copy()
univariate_df.columns = ['ds', 'y']


# LSTM对输入数据的大小敏感，需要对输入数据做标准化处理
# 使用MinMaxScaler将数据映射到0-1区间
from sklearn.preprocessing import MinMaxScaler
data = univariate_df.filter(['y'])
dataset = data.values
scaler = MinMaxScaler(feature_range=(-1, 0))
scaled_data = scaler.fit_transform(dataset)

scaled_data[-10:]
# Out:
# array([[-0.64815831],
#        [-0.55628716],
#        [-0.55051144],
#        [-0.55767854],
#        [-0.55965146],
#        [-0.55870838],
#        [-0.60547025],
#        [-0.64730482],
#        [-0.56678289],
#        [-0.59454232]])

# %%
def check(du):
    #正态检测
    u = du.mean()
    # 计算标准差
    std = du.std()
    # 计算P值
    res=kstest(du.astype(float),  'norm', (u, std))[1]
    print(res)
    # 判断p值是否服从正态分布，p<=0.05 则服从正态分布，否则不服从。
    if res<=0.05:
        print('该列数据服从正态分布------------')
        print('均值为：%.3f，标准差为：%.3f' % (u, std))
        print('------------------------------')
    else:
        print("错误")

def sta(sta_du):
    stas = []
    u = sta_du.mean()
    std = sta_du.std()
    for i in sta_du:
        stas.append((i-u)/(std*std))
    return stas

# %%
du_day_max = df['最高温度']
du_day_min = df['最低温度']

#温度标准化
from scipy.stats import kstest
check(du_day_max)
check(du_day_min)
du_day_max = sta(du_day_max)
du_day_min = sta(du_day_min)
# Out:
# 9.644418929685959e-10
# 该列数据服从正态分布------------
# 均值为：27.867，标准差为：6.178
# ------------------------------
# 2.9161076470993697e-19
# 该列数据服从正态分布------------
# 均值为：20.501，标准差为：5.998
# ------------------------------

# %%
f, ax = plt.subplots(nrows=1, ncols=1, figsize=(20, 6))
sns.distplot(du_day_min, ax=ax,color='green',label='du_day_max') #直方图和核密度图的结合，查看单个连续型变量的分布
sns.distplot(du_day_max, ax=ax, color='orange',label='du_day_min') #直方图和核密度图的结合，查看单个连续型变量的分布
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
du_day_max = list(map(list, zip(du_day_max)))
du_day_min = list(map(list, zip(du_day_min)))

# %%
look_back = 7 # 96
# 将数据分为训练集、测试集
train, test = scaled_data[:train_size-look_back,:], scaled_data[train_size-look_back:,:]

# 生成t-x数据
def create_dataset(dataset, look_back):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# 设置随机种子，保证复现

np.random.seed(7)


x_train, y_train = create_dataset(train, look_back)
x_test, y_test = create_dataset(test, look_back)

#添加特征列
x_train = np.append(x_train,du_day_max[0:train_size-look_back*2],axis=1)
x_train = np.append(x_train,du_day_min[0:train_size-look_back*2],axis=1)
x_test = np.append(x_test,du_day_max[train_size:],axis=1)
x_test = np.append(x_test,du_day_min[train_size:],axis=1)


# LSTM网络的输入为【批次大小(行数)，时间步长，特征数量(列数)】
# 将数据转换为符合输入的格式
x_train = np.reshape(x_train, (x_train.shape[0], 1, x_train.shape[1]))
x_test = np.reshape(x_test, (x_test.shape[0], 1, x_test.shape[1]))

print(len(x_train), len(x_test))
# Out:
# 869 90

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM

# 创建LSTM模型，拟合数据
model = Sequential()

# 添加128个LSTM神经元的隐层网络
model.add(LSTM(128, input_shape=(x_train.shape[1], x_train.shape[2]))) #return_sequences=True
#model.add(LSTM(64, return_sequences=False))
model.add(Dense(30))
#model.add(Dense(1))

# 损失函数与adam优化器
model.compile(optimizer='adam', loss='mean_squared_error')

# 训练数据10期, batch_size:一次训练抓取的样本数量
model.fit(x_train, y_train, batch_size=16, epochs=150 )  #validation_data=(x_test, y_test)

model.summary()
# Out:
# Epoch 1/150
# 55/55 [==============================] - 1s 2ms/step - loss: 0.1829
# Epoch 2/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0093
# Epoch 3/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0078
# Epoch 4/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0077
# Epoch 5/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0075
# Epoch 6/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0074
# Epoch 7/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0073
# Epoch 8/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0072
# Epoch 9/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0071
# Epoch 10/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0071
# Epoch 11/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0070
# Epoch 12/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0069
# Epoch 13/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0069
# Epoch 14/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0068
# Epoch 15/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0067
# Epoch 16/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0067
# Epoch 17/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0067
# Epoch 18/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0065
# Epoch 19/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0066
# Epoch 20/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0065
# Epoch 21/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0064
# Epoch 22/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0064
# Epoch 23/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0064
# Epoch 24/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0064
# Epoch 25/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0064
# Epoch 26/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 27/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 28/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 29/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 30/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 31/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 32/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 33/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 34/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 35/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 36/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 37/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 38/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 39/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 40/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 41/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 42/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 43/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 44/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 45/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 46/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 47/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 48/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 49/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 50/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 51/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 52/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 53/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 54/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 55/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 56/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 57/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 58/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 59/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 60/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 61/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 62/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 63/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 64/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 65/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 66/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 67/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 68/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 69/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 70/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 71/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 72/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 73/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 74/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 75/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 76/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 77/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 78/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 79/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 80/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 81/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 82/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 83/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 84/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 85/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 86/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 87/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 88/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 89/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 90/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 91/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 92/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 93/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 94/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 95/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 96/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 97/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 98/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 99/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 100/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 101/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 102/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 103/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 104/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 105/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 106/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 107/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 108/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 109/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 110/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 111/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 112/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 113/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 114/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 115/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 116/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 117/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 118/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 119/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 120/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 121/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 122/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 123/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 124/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 125/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 126/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 127/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 128/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 129/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 130/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 131/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 132/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 133/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 134/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 135/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 136/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 137/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 138/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 139/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 140/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0059
# Epoch 141/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 142/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0059
# Epoch 143/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0059
# Epoch 144/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 145/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 146/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 147/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 148/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 149/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 150/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0060
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 128)               70656
#
#  dense (Dense)               (None, 30)                3870
#
# =================================================================
# Total params: 74,526
# Trainable params: 74,526
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 预测
#train_predict = model.predict(x_train)
test_predict = model.predict(x_test) # 3个月的数据

# 前面把数据缩放到0-1范围。
# 现在跟实际值做比较，将预测值反标准化，从0-1范围转换为原数据范围
#train_predict = scaler.inverse_transform(train_predict)
#y_train = scaler.inverse_transform([y_train])

test_predict = scaler.inverse_transform(test_predict)
y_test = scaler.inverse_transform([y_test])

# 评估RMSE误差
score_rmse = np.sqrt(mean_squared_error(y_test[0], test_predict[:,1]))
score_mae = mean_absolute_error(y_test[0], test_predict[:,1])
print(Fore.GREEN + 'RMSE: {}'.format(score_rmse))
from sklearn.metrics import r2_score
print('R2-score:',r2_score(y_test[0], test_predict[:,1]))
# Out:
# RMSE: 9138.393669196597
# R2-score: 0.47053515325817286

# %%
# 准备画图 - 训练数据
x_train_ticks = univariate_df.head(train_size)['ds']
y_train = univariate_df.head(train_size)['y']
x_test_ticks = univariate_df.tail(test_predict[:,0].size)['ds']

# 准备画图 - 测试数据
f, ax = plt.subplots(1)
f.set_figheight(6)
f.set_figwidth(15)

sns.lineplot(x=x_train_ticks[-30:], y=y_train[-30:], ax=ax, label='Train Set') #navajowhite
sns.lineplot(x=x_test_ticks, y=test_predict[:,0], ax=ax, color='green', label='Prediction') #navajowhite
sns.lineplot(x=x_test_ticks, y=y_test[0], ax=ax, color='orange', label='Ground truth') #navajowhite

ax.set_title(f'Prediction \n MAE: {score_mae:.2f}, RMSE: {score_rmse:.2f}', fontsize=14)
ax.set_xlabel(xlabel='Date', fontsize=14)
ax.set_ylabel(ylabel='有功功率最大值', fontsize=14)
plt.show()

# %%
day_index = pd.date_range(start='2021-06-03',end='2021-08-31',freq='D')
day_index = pd.DataFrame(day_index,columns=['date_day'])

test_predict = pd.DataFrame(test_predict[:,0],columns=['sum'])
test_predict = pd.concat((test_predict,day_index),axis=1)
test_predict.index = test_predict['date_day']

# %%
for i in range(test_predict['sum'].count()):
    if (test_predict.iloc[i,0] == test_predict['sum'].max()):
        print("\n最大值为：",test_predict.iloc[i,0])
        print("最大日期为：",test_predict.iloc[i,1])
    if (test_predict.iloc[i,0] == test_predict['sum'].min()):
        print("\n最小值为：",test_predict.iloc[i,0])
        print("最小日期为：",test_predict.iloc[i,1])
print(f'\nPrediction \n MAE: {score_mae:.2f}, RMSE: {score_rmse:.2f}')
# Out:
# 最小值为： 59146.34
# 最小日期为： 2021-06-15 00:00:00
#
# 最大值为： 109176.56
# 最大日期为： 2021-07-30 00:00:00
#
# Prediction
#  MAE: 7396.77, RMSE: 9138.39

# %% [markdown]
# ## LSTM商业最小功率三十天预测

# %%
test_size = 90  #预测测试值范围
train_size = len(df) - test_size  #预测训练值范围
df = df.fillna(0)
univariate_df = df[['date', '有功功率最小值（kw）']].copy()
univariate_df.columns = ['ds', 'y']


# LSTM对输入数据的大小敏感，需要对输入数据做标准化处理
# 使用MinMaxScaler将数据映射到0-1区间
from sklearn.preprocessing import MinMaxScaler
data = univariate_df.filter(['y'])
dataset = data.values
scaler = MinMaxScaler(feature_range=(-1, 0))
scaled_data = scaler.fit_transform(dataset)

scaled_data[-10:]
# Out:
# array([[-0.20314153],
#        [-0.20464006],
#        [-0.18075927],
#        [-0.18756704],
#        [-0.21995778],
#        [-0.27443099],
#        [-0.23757244],
#        [-0.20604008],
#        [-0.22963415],
#        [-0.22028756]])

# %%
def check(du):
    #正态检测
    u = du.mean()
    # 计算标准差
    std = du.std()
    # 计算P值
    res=kstest(du.astype(float),  'norm', (u, std))[1]
    print(res)
    # 判断p值是否服从正态分布，p<=0.05 则服从正态分布，否则不服从。
    if res<=0.05:
        print('该列数据服从正态分布------------')
        print('均值为：%.3f，标准差为：%.3f' % (u, std))
        print('------------------------------')
    else:
        print("错误")

def sta(sta_du):
    stas = []
    u = sta_du.mean()
    std = sta_du.std()
    for i in sta_du:
        stas.append((i-u)/(std*std))
    return stas

# %%
du_day_max = df['最高温度']
du_day_min = df['最低温度']

#温度标准化
from scipy.stats import kstest
check(du_day_max)
check(du_day_min)
du_day_max = sta(du_day_max)
du_day_min = sta(du_day_min)
# Out:
# 9.644418929685959e-10
# 该列数据服从正态分布------------
# 均值为：27.867，标准差为：6.178
# ------------------------------
# 2.9161076470993697e-19
# 该列数据服从正态分布------------
# 均值为：20.501，标准差为：5.998
# ------------------------------

# %%
f, ax = plt.subplots(nrows=1, ncols=1, figsize=(20, 6))
sns.distplot(du_day_min, ax=ax,color='green',label='du_day_max') #直方图和核密度图的结合，查看单个连续型变量的分布
sns.distplot(du_day_max, ax=ax, color='orange',label='du_day_min') #直方图和核密度图的结合，查看单个连续型变量的分布
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
du_day_max = list(map(list, zip(du_day_max)))
du_day_min = list(map(list, zip(du_day_min)))

# %%
look_back = 7 # 96
# 将数据分为训练集、测试集
train, test = scaled_data[:train_size-look_back,:], scaled_data[train_size-look_back:,:]

# 生成t-x数据
def create_dataset(dataset, look_back):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# 设置随机种子，保证复现

np.random.seed(7)


x_train, y_train = create_dataset(train, look_back)
x_test, y_test = create_dataset(test, look_back)

#添加特征列
x_train = np.append(x_train,du_day_max[0:train_size-look_back*2],axis=1)
x_train = np.append(x_train,du_day_min[0:train_size-look_back*2],axis=1)
x_test = np.append(x_test,du_day_max[train_size:],axis=1)
x_test = np.append(x_test,du_day_min[train_size:],axis=1)


# LSTM网络的输入为【批次大小(行数)，时间步长，特征数量(列数)】
# 将数据转换为符合输入的格式
x_train = np.reshape(x_train, (x_train.shape[0], 1, x_train.shape[1]))
x_test = np.reshape(x_test, (x_test.shape[0], 1, x_test.shape[1]))

print(len(x_train), len(x_test))
# Out:
# 869 90

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM

# 创建LSTM模型，拟合数据
model = Sequential()

# 添加128个LSTM神经元的隐层网络
model.add(LSTM(128, input_shape=(x_train.shape[1], x_train.shape[2]))) #return_sequences=True
#model.add(LSTM(64, return_sequences=False))
model.add(Dense(30))
#model.add(Dense(1))

# 损失函数与adam优化器
model.compile(optimizer='adam', loss='mean_squared_error')

# 训练数据10期, batch_size:一次训练抓取的样本数量
model.fit(x_train, y_train, batch_size=16, epochs=150 )  #validation_data=(x_test, y_test)

model.summary()
# Out:
# Epoch 1/150
# 55/55 [==============================] - 1s 2ms/step - loss: 0.0842
# Epoch 2/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0171
# Epoch 3/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0162
# Epoch 4/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0160
# Epoch 5/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0156
# Epoch 6/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0153
# Epoch 7/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0150
# Epoch 8/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0148
# Epoch 9/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0146
# Epoch 10/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0145
# Epoch 11/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0144
# Epoch 12/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0142
# Epoch 13/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0142
# Epoch 14/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0141
# Epoch 15/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0141
# Epoch 16/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0141
# Epoch 17/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0142
# Epoch 18/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0140
# Epoch 19/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0140
# Epoch 20/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0140
# Epoch 21/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0139
# Epoch 22/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0139
# Epoch 23/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0140
# Epoch 24/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0140
# Epoch 25/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0140
# Epoch 26/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0140
# Epoch 27/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0140
# Epoch 28/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0138
# Epoch 29/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0139
# Epoch 30/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0140
# Epoch 31/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0138
# Epoch 32/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0142
# Epoch 33/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0137
# Epoch 34/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0138
# Epoch 35/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0137
# Epoch 36/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0138
# Epoch 37/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0138
# Epoch 38/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0137
# Epoch 39/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0137
# Epoch 40/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0141
# Epoch 41/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0138
# Epoch 42/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0136
# Epoch 43/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0137
# Epoch 44/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0138
# Epoch 45/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0138
# Epoch 46/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0136
# Epoch 47/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0137
# Epoch 48/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0138
# Epoch 49/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0136
# Epoch 50/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0136
# Epoch 51/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0136
# Epoch 52/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0135
# Epoch 53/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0137
# Epoch 54/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0134
# Epoch 55/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0137
# Epoch 56/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0136
# Epoch 57/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0135
# Epoch 58/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0135
# Epoch 59/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0135
# Epoch 60/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0137
# Epoch 61/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0136
# Epoch 62/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0134
# Epoch 63/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0133
# Epoch 64/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0136
# Epoch 65/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0135
# Epoch 66/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0133
# Epoch 67/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0133
# Epoch 68/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0133
# Epoch 69/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0134
# Epoch 70/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0135
# Epoch 71/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0132
# Epoch 72/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0132
# Epoch 73/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0132
# Epoch 74/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0133
# Epoch 75/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0132
# Epoch 76/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0132
# Epoch 77/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0133
# Epoch 78/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0131
# Epoch 79/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0133
# Epoch 80/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0133
# Epoch 81/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0136
# Epoch 82/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0131
# Epoch 83/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0130
# Epoch 84/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0131
# Epoch 85/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0135
# Epoch 86/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0132
# Epoch 87/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0132
# Epoch 88/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0131
# Epoch 89/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0132
# Epoch 90/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0130
# Epoch 91/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0129
# Epoch 92/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0132
# Epoch 93/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0132
# Epoch 94/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0131
# Epoch 95/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0130
# Epoch 96/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0131
# Epoch 97/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0130
# Epoch 98/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0129
# Epoch 99/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0132
# Epoch 100/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0130
# Epoch 101/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0130
# Epoch 102/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0131
# Epoch 103/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0131
# Epoch 104/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0131
# Epoch 105/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0131
# Epoch 106/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0131
# Epoch 107/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0129
# Epoch 108/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0129
# Epoch 109/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0129
# Epoch 110/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0130
# Epoch 111/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0128
# Epoch 112/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0129
# Epoch 113/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0130
# Epoch 114/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0129
# Epoch 115/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0130
# Epoch 116/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0130
# Epoch 117/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0130
# Epoch 118/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0130
# Epoch 119/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0128
# Epoch 120/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0127
# Epoch 121/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0128
# Epoch 122/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0128
# Epoch 123/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0130
# Epoch 124/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0128
# Epoch 125/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0128
# Epoch 126/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0130
# Epoch 127/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0127
# Epoch 128/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0127
# Epoch 129/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0127
# Epoch 130/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0127
# Epoch 131/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0128
# Epoch 132/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0127
# Epoch 133/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0129
# Epoch 134/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0127
# Epoch 135/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0128
# Epoch 136/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0127
# Epoch 137/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0130
# Epoch 138/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0126
# Epoch 139/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0127
# Epoch 140/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0126
# Epoch 141/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0127
# Epoch 142/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0127
# Epoch 143/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0128
# Epoch 144/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0128
# Epoch 145/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0125
# Epoch 146/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0127
# Epoch 147/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0127
# Epoch 148/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0126
# Epoch 149/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0126
# Epoch 150/150
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0126
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 128)               70656
#
#  dense_1 (Dense)             (None, 30)                3870
#
# =================================================================
# Total params: 74,526
# Trainable params: 74,526
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 预测
#train_predict = model.predict(x_train)
test_predict = model.predict(x_test) # 3个月的数据

# 前面把数据缩放到0-1范围。
# 现在跟实际值做比较，将预测值反标准化，从0-1范围转换为原数据范围
#train_predict = scaler.inverse_transform(train_predict)
#y_train = scaler.inverse_transform([y_train])

test_predict = scaler.inverse_transform(test_predict)
y_test = scaler.inverse_transform([y_test])

# 评估RMSE误差
score_rmse = np.sqrt(mean_squared_error(y_test[0], test_predict[:,1]))
score_mae = mean_absolute_error(y_test[0], test_predict[:,1])
print(Fore.GREEN + 'RMSE: {}'.format(score_rmse))
from sklearn.metrics import r2_score
print('R2-score:',r2_score(y_test[0], test_predict[:,1]))
# Out:
# RMSE: 2906.8901985997927
# R2-score: 0.1843842451384614

# %%
# 准备画图 - 训练数据
x_train_ticks = univariate_df.head(train_size)['ds']
y_train = univariate_df.head(train_size)['y']
x_test_ticks = univariate_df.tail(test_predict[:,0].size)['ds']

# 准备画图 - 测试数据
f, ax = plt.subplots(1)
f.set_figheight(6)
f.set_figwidth(15)

sns.lineplot(x=x_train_ticks[-30:], y=y_train[-30:], ax=ax, label='Train Set') #navajowhite
sns.lineplot(x=x_test_ticks, y=test_predict[:,0], ax=ax, color='green', label='Prediction') #navajowhite
sns.lineplot(x=x_test_ticks, y=y_test[0], ax=ax, color='orange', label='Ground truth') #navajowhite

ax.set_title(f'Prediction \n MAE: {score_mae:.2f}, RMSE: {score_rmse:.2f}', fontsize=14)
ax.set_xlabel(xlabel='Date', fontsize=14)
ax.set_ylabel(ylabel='有功功率最大值', fontsize=14)
plt.show()

# %%
day_index = pd.date_range(start='2021-06-03',end='2021-08-31',freq='D')
day_index = pd.DataFrame(day_index,columns=['date_day'])

test_predict = pd.DataFrame(test_predict[:,0],columns=['sum'])
test_predict = pd.concat((test_predict,day_index),axis=1)
test_predict.index = test_predict['date_day']

# %%
for i in range(test_predict['sum'].count()):
    if (test_predict.iloc[i,0] == test_predict['sum'].max()):
        print("\n最大值为：",test_predict.iloc[i,0])
        print("最大日期为：",test_predict.iloc[i,1])
    if (test_predict.iloc[i,0] == test_predict['sum'].min()):
        print("\n最小值为：",test_predict.iloc[i,0])
        print("最小日期为：",test_predict.iloc[i,1])
print(f'\nPrediction \n MAE: {score_mae:.2f}, RMSE: {score_rmse:.2f}')
# Out:
# 最大值为： 22511.504
# 最大日期为： 2021-07-28 00:00:00
#
# 最小值为： 12732.477
# 最小日期为： 2021-08-10 00:00:00
#
# Prediction
#  MAE: 1812.37, RMSE: 2906.89
